# %% [markdown]
# # LogView: Evaluation using the Road Traffic Fine Management Event Log #

# %% [markdown]
# #### Introduction ####
# For our evaluation, we conducted an extensive analysis using the Road Traffic Fine Management (RTFM) event log. The log records data about the process of managing and handling road traffic fines by a local police force in Italy and has been used often in process mining literature.
#
# #### Process Description ####
# The RTFM log contains 561,470 events grouped into 150,370 cases recorded between January 2000 and June 2013, including 11 different activities and 12 data attributes.
# Each case begins with a **Create Fine** event, which specifies the fine amount and other attributes. Offenders have the option to pay the fine at any time, as indicated by a **Payment** event and its _PaymentAmount_ attribute, which captures the amount paid in one transaction. A _TotalPaymentAmount_ attribute also tracks the cumulative amount paid. A **Send Fine** event triggers a notification letter to the offender, whose receipt is documented by an **Insert Fine Notification** event, followed by a possible ***Add Penalty** event, which updates the amount to be paid. Sending the letter incurs postage costs, captured by the _expense_ attribute. Finally, a **Send for Credit Collection** event sends unpaid cases to a collection agency. Offenders have the option to appeal against the fine to a prefecture or judge. If the fine is overturned this is recorded in the _dismissal_ attribute.
#
# #### Data ####
# The event log is already provided in the dataset folder.\
# More details about the event log can be found [here](https://link.springer.com/article/10.1007/s00607-015-0441-1#Sec8).\
# The raw event log files can also be downloaded [here](https://data.4tu.nl/articles/dataset/Road_Traffic_Fine_Management_Process/12683249?file=24018146).

# %% [markdown]
# ## Reading the event log file ##

# %%
import pandas as pd
import pm4py

CASE_ID_COL = 'Case ID'
TIMESTAMP_COL = 'Complete Timestamp'
ACTIVITY_COL = 'Activity'

# Read event log
path_to_log = "./dataset/Road_Traffic_Fine_Management_Process.csv"
df = pd.read_csv(path_to_log, dtype={'Resource': str, 'matricola': str}, parse_dates=[TIMESTAMP_COL])
df = df.sort_values([CASE_ID_COL, TIMESTAMP_COL], ignore_index=True)
log = pm4py.format_dataframe(df, case_id=CASE_ID_COL, activity_key=ACTIVITY_COL, timestamp_key=TIMESTAMP_COL)

# Create a log view object to interact with the framework
from logview.utils import LogViewBuilder
log_view = LogViewBuilder.build_log_view(log)

# %%
# View the read log for debug
log.head(30)
# Out:
#    Case ID                          Activity Resource  \
# 0       A1                       Create Fine      561
# 1       A1                         Send Fine      NaN
# 2     A100                       Create Fine      561
# 3     A100                         Send Fine      NaN
# 4     A100          Insert Fine Notification      NaN
# 5     A100                       Add penalty      NaN
# 6     A100        Send for Credit Collection      NaN
# 7   A10000                       Create Fine      561
# 8   A10000                         Send Fine      NaN
# 9   A10000          Insert Fine Notification      NaN
# 10  A10000                       Add penalty      NaN
# 11  A10000                           Payment      NaN
# 12  A10001                       Create Fine      537
# 13  A10001                         Send Fine      NaN
# 14  A10001          Insert Fine Notification      NaN
# 15  A10001  Insert Date Appeal to Prefecture      NaN
# 16  A10001                       Add penalty      NaN
# 17  A10001         Send Appeal to Prefecture      NaN
# 18  A10004                       Create Fine      537
# 19  A10004                         Send Fine      NaN
# 20  A10004          Insert Fine Notification      NaN
# 21  A10004                       Add penalty      NaN
# 22  A10004        Send for Credit Collection      NaN
# 23  A10005                       Create Fine      537
# 24  A10005                           Payment      NaN
# 25  A10007                       Create Fine      537
# 26  A10007                           Payment      NaN
# 27  A10008                       Create Fine      537
# 28  A10008                         Send Fine      NaN
# 29  A10008          Insert Fine Notification      NaN
#
#           Complete Timestamp    Variant  Variant index  amount  article  \
# 0  2006-07-24 00:00:00+00:00  Variant 3              3    35.0    157.0
# 1  2006-12-05 00:00:00+00:00  Variant 3              3     NaN      NaN
# 2  2006-08-02 00:00:00+00:00  Variant 1              1    35.0    157.0
# 3  2006-12-12 00:00:00+00:00  Variant 1              1     NaN      NaN
# 4  2007-01-15 00:00:00+00:00  Variant 1              1     NaN      NaN
# 5  2007-03-16 00:00:00+00:00  Variant 1              1    71.5      NaN
# 6  2009-03-30 00:00:00+00:00  Variant 1              1     NaN      NaN
# 7  2007-03-09 00:00:00+00:00  Variant 4              4    36.0    157.0
# 8  2007-07-17 00:00:00+00:00  Variant 4              4     NaN      NaN
# 9  2007-08-02 00:00:00+00:00  Variant 4              4     NaN      NaN
# 10 2007-10-01 00:00:00+00:00  Variant 4              4    74.0      NaN
# 11 2008-09-09 00:00:00+00:00  Variant 4              4     NaN      NaN
# 12 2007-03-19 00:00:00+00:00  Variant 8              8    36.0    157.0
# 13 2007-07-17 00:00:00+00:00  Variant 8              8     NaN      NaN
# 14 2007-07-25 00:00:00+00:00  Variant 8              8     NaN      NaN
# 15 2007-08-02 00:00:00+00:00  Variant 8              8     NaN      NaN
# 16 2007-09-23 00:00:00+00:00  Variant 8              8    74.0      NaN
# 17 2007-09-24 00:00:00+00:00  Variant 8              8     NaN      NaN
# 18 2007-03-20 00:00:00+00:00  Variant 1              1    36.0    157.0
# 19 2007-07-17 00:00:00+00:00  Variant 1              1     NaN      NaN
# 20 2007-07-24 00:00:00+00:00  Variant 1              1     NaN      NaN
# 21 2007-09-22 00:00:00+00:00  Variant 1              1    74.0      NaN
# 22 2009-03-30 00:00:00+00:00  Variant 1              1     NaN      NaN
# 23 2007-03-20 00:00:00+00:00  Variant 2              2    36.0    157.0
# 24 2007-03-21 00:00:00+00:00  Variant 2              2     NaN      NaN
# 25 2007-03-20 00:00:00+00:00  Variant 2              2    36.0    157.0
# 26 2007-03-23 00:00:00+00:00  Variant 2              2     NaN      NaN
# 27 2007-03-20 00:00:00+00:00  Variant 1              1    36.0    157.0
# 28 2007-07-17 00:00:00+00:00  Variant 1              1     NaN      NaN
# 29 2007-08-02 00:00:00+00:00  Variant 1              1     NaN      NaN
#
#    dismissal  expense  ... notificationType paymentAmount points  \
# 0        NIL      NaN  ...              NaN           NaN    0.0
# 1        NaN     11.0  ...              NaN           NaN    NaN
# 2        NIL      NaN  ...              NaN           NaN    0.0
# 3        NaN     11.0  ...              NaN           NaN    NaN
# 4        NaN      NaN  ...                P           NaN    NaN
# 5        NaN      NaN  ...              NaN           NaN    NaN
# 6        NaN      NaN  ...              NaN           NaN    NaN
# 7        NIL      NaN  ...              NaN           NaN    0.0
# 8        NaN     13.0  ...              NaN           NaN    NaN
# 9        NaN      NaN  ...                P           NaN    NaN
# 10       NaN      NaN  ...              NaN           NaN    NaN
# 11       NaN      NaN  ...              NaN          87.0    NaN
# 12       NIL      NaN  ...              NaN           NaN    0.0
# 13       NaN     13.0  ...              NaN           NaN    NaN
# 14       NaN      NaN  ...                P           NaN    NaN
# 15       NaN      NaN  ...              NaN           NaN    NaN
# 16       NaN      NaN  ...              NaN           NaN    NaN
# 17         #      NaN  ...              NaN           NaN    NaN
# 18       NIL      NaN  ...              NaN           NaN    0.0
# 19       NaN     13.0  ...              NaN           NaN    NaN
# 20       NaN      NaN  ...                P           NaN    NaN
# 21       NaN      NaN  ...              NaN           NaN    NaN
# 22       NaN      NaN  ...              NaN           NaN    NaN
# 23       NIL      NaN  ...              NaN           NaN    0.0
# 24       NaN      NaN  ...              NaN          36.0    NaN
# 25       NIL      NaN  ...              NaN           NaN    0.0
# 26       NaN      NaN  ...              NaN          36.0    NaN
# 27       NIL      NaN  ...              NaN           NaN    0.0
# 28       NaN     13.0  ...              NaN           NaN    NaN
# 29       NaN      NaN  ...                P           NaN    NaN
#
#    totalPaymentAmount  vehicleClass  case:concept:name  \
# 0                 0.0             A                 A1
# 1                 NaN           NaN                 A1
# 2                 0.0             A               A100
# 3                 NaN           NaN               A100
# 4                 NaN           NaN               A100
# 5                 NaN           NaN               A100
# 6                 NaN           NaN               A100
# 7                 0.0             A             A10000
# 8                 NaN           NaN             A10000
# 9                 NaN           NaN             A10000
# 10                NaN           NaN             A10000
# 11               87.0           NaN             A10000
# 12                0.0             A             A10001
# 13                NaN           NaN             A10001
# 14                NaN           NaN             A10001
# 15                NaN           NaN             A10001
# 16                NaN           NaN             A10001
# 17                NaN           NaN             A10001
# 18                0.0             A             A10004
# 19                NaN           NaN             A10004
# 20                NaN           NaN             A10004
# 21                NaN           NaN             A10004
# 22                NaN           NaN             A10004
# 23                0.0             A             A10005
# 24               36.0           NaN             A10005
# 25                0.0             A             A10007
# 26               36.0           NaN             A10007
# 27                0.0             A             A10008
# 28                NaN           NaN             A10008
# 29                NaN           NaN             A10008
#
#                         concept:name            time:timestamp @@index  \
# 0                        Create Fine 2006-07-24 00:00:00+00:00       0
# 1                          Send Fine 2006-12-05 00:00:00+00:00       1
# 2                        Create Fine 2006-08-02 00:00:00+00:00       2
# 3                          Send Fine 2006-12-12 00:00:00+00:00       3
# 4           Insert Fine Notification 2007-01-15 00:00:00+00:00       4
# 5                        Add penalty 2007-03-16 00:00:00+00:00       5
# 6         Send for Credit Collection 2009-03-30 00:00:00+00:00       6
# 7                        Create Fine 2007-03-09 00:00:00+00:00       7
# 8                          Send Fine 2007-07-17 00:00:00+00:00       8
# 9           Insert Fine Notification 2007-08-02 00:00:00+00:00       9
# 10                       Add penalty 2007-10-01 00:00:00+00:00      10
# 11                           Payment 2008-09-09 00:00:00+00:00      11
# 12                       Create Fine 2007-03-19 00:00:00+00:00      12
# 13                         Send Fine 2007-07-17 00:00:00+00:00      13
# 14          Insert Fine Notification 2007-07-25 00:00:00+00:00      14
# 15  Insert Date Appeal to Prefecture 2007-08-02 00:00:00+00:00      15
# 16                       Add penalty 2007-09-23 00:00:00+00:00      16
# 17         Send Appeal to Prefecture 2007-09-24 00:00:00+00:00      17
# 18                       Create Fine 2007-03-20 00:00:00+00:00      18
# 19                         Send Fine 2007-07-17 00:00:00+00:00      19
# 20          Insert Fine Notification 2007-07-24 00:00:00+00:00      20
# 21                       Add penalty 2007-09-22 00:00:00+00:00      21
# 22        Send for Credit Collection 2009-03-30 00:00:00+00:00      22
# 23                       Create Fine 2007-03-20 00:00:00+00:00      23
# 24                           Payment 2007-03-21 00:00:00+00:00      24
# 25                       Create Fine 2007-03-20 00:00:00+00:00      25
# 26                           Payment 2007-03-23 00:00:00+00:00      26
# 27                       Create Fine 2007-03-20 00:00:00+00:00      27
# 28                         Send Fine 2007-07-17 00:00:00+00:00      28
# 29          Insert Fine Notification 2007-08-02 00:00:00+00:00      29
#
#    @@case_index
# 0             0
# 1             0
# 2             1
# 3             1
# 4             1
# 5             1
# 6             1
# 7             2
# 8             2
# 9             2
# 10            2
# 11            2
# 12            3
# 13            3
# 14            3
# 15            3
# 16            3
# 17            3
# 18            4
# 19            4
# 20            4
# 21            4
# 22            4
# 23            5
# 24            5
# 25            6
# 26            6
# 27            7
# 28            7
# 29            7
#
# [30 rows x 23 columns]

# %% [markdown]
# ## Exploring Unpaid Cases ##
# **Goal**: Find scenarios in which traffic fines are not fully paid.\
# Our Initial Hypothesis: Unpaid cases are those where there is no **Payment** activity.
#
# _This is our initial hypothesis, which is intentionally not precise as we are in exploratory settings._

# %%
from logview.predicate import *

# Run a query to find all cases that do not include activity Payment: this is assumed to indicate unpaid activities.
query_no_p = Query('unpaid', [NotEqToConstant('Activity', 'Payment')])
rs_no_p, complement_no_p = log_view.evaluate_query('rs_unpaid', log, query_no_p)

rs_no_p.head(10)
# Out:
#    Case ID                    Activity Resource        Complete Timestamp  \
# 0       A1                 Create Fine      561 2006-07-24 00:00:00+00:00
# 1       A1                   Send Fine      NaN 2006-12-05 00:00:00+00:00
# 2     A100                 Create Fine      561 2006-08-02 00:00:00+00:00
# 3     A100                   Send Fine      NaN 2006-12-12 00:00:00+00:00
# 4     A100    Insert Fine Notification      NaN 2007-01-15 00:00:00+00:00
# 5     A100                 Add penalty      NaN 2007-03-16 00:00:00+00:00
# 6     A100  Send for Credit Collection      NaN 2009-03-30 00:00:00+00:00
# 12  A10001                 Create Fine      537 2007-03-19 00:00:00+00:00
# 13  A10001                   Send Fine      NaN 2007-07-17 00:00:00+00:00
# 14  A10001    Insert Fine Notification      NaN 2007-07-25 00:00:00+00:00
#
#       Variant  Variant index  amount  article dismissal  expense  ...  \
# 0   Variant 3              3    35.0    157.0       NIL      NaN  ...
# 1   Variant 3              3     NaN      NaN       NaN     11.0  ...
# 2   Variant 1              1    35.0    157.0       NIL      NaN  ...
# 3   Variant 1              1     NaN      NaN       NaN     11.0  ...
# 4   Variant 1              1     NaN      NaN       NaN      NaN  ...
# 5   Variant 1              1    71.5      NaN       NaN      NaN  ...
# 6   Variant 1              1     NaN      NaN       NaN      NaN  ...
# 12  Variant 8              8    36.0    157.0       NIL      NaN  ...
# 13  Variant 8              8     NaN      NaN       NaN     13.0  ...
# 14  Variant 8              8     NaN      NaN       NaN      NaN  ...
#
#    notificationType paymentAmount points totalPaymentAmount  vehicleClass  \
# 0               NaN           NaN    0.0                0.0             A
# 1               NaN           NaN    NaN                NaN           NaN
# 2               NaN           NaN    0.0                0.0             A
# 3               NaN           NaN    NaN                NaN           NaN
# 4                 P           NaN    NaN                NaN           NaN
# 5               NaN           NaN    NaN                NaN           NaN
# 6               NaN           NaN    NaN                NaN           NaN
# 12              NaN           NaN    0.0                0.0             A
# 13              NaN           NaN    NaN                NaN           NaN
# 14                P           NaN    NaN                NaN           NaN
#
#     case:concept:name                concept:name            time:timestamp  \
# 0                  A1                 Create Fine 2006-07-24 00:00:00+00:00
# 1                  A1                   Send Fine 2006-12-05 00:00:00+00:00
# 2                A100                 Create Fine 2006-08-02 00:00:00+00:00
# 3                A100                   Send Fine 2006-12-12 00:00:00+00:00
# 4                A100    Insert Fine Notification 2007-01-15 00:00:00+00:00
# 5                A100                 Add penalty 2007-03-16 00:00:00+00:00
# 6                A100  Send for Credit Collection 2009-03-30 00:00:00+00:00
# 12             A10001                 Create Fine 2007-03-19 00:00:00+00:00
# 13             A10001                   Send Fine 2007-07-17 00:00:00+00:00
# 14             A10001    Insert Fine Notification 2007-07-25 00:00:00+00:00
#
#    @@index @@case_index
# 0        0            0
# 1        1            0
# 2        2            1
# 3        3            1
# 4        4            1
# 5        5            1
# 6        6            1
# 12      12            3
# 13      13            3
# 14      14            3
#
# [10 rows x 23 columns]

# %% [markdown]
# We check that our query has been added to the registry

# %%
_ = log_view.get_summary()
# Out:
# +----+--------------------+---------+--------------+----------+
# |    | source_log         | query   | result_set   | labels   |
# |----+--------------------+---------+--------------+----------|
# |  0 | initial_source_log | unpaid  | rs_unpaid    | []       |
# +----+--------------------+---------+--------------+----------+
# +----+---------+---------------------------------+
# |    | query   | predicates                      |
# |----+---------+---------------------------------|
# |  0 | unpaid  | (Activity not in { 'Payment' }) |
# +----+---------+---------------------------------+

# %% [markdown]
# We then characterize the result using our _Result Set Characterizer_. We're interested in looking into cardinality, to see how much we filtered out and a few examples.

# %%
_ = log_view.characterize_result_set_with_reference_log('rs_unpaid', log, characterizer_name='set-cardinality')
_ = log_view.characterize_result_set_with_reference_log('rs_unpaid', log, characterizer_name='random-example-retriever')
# Out:
# Number of case_id in rs_unpaid: 80655
# Number of case_id in initial_source_log: 150370
# Sample from initial_source_log
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity    |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense |   lastSent | lifecycle:transition   |   matricola |   notificationType |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name   | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------|
# | 316377 | S123642   | Create Fine |         58 | 2008-08-18 00:00:00+00:00 | Variant 2 |               2 |       36 |       158 | NIL         |       nan |        nan | complete               |         nan |                nan |             nan |        0 |                    0 | A              | S123642             | Create Fine    | 2008-08-18 00:00:00+00:00 |    316377 |          85100 |
# | 316378 | S123642   | Payment     |        nan | 2008-08-19 00:00:00+00:00 | Variant 2 |               2 |      nan |       nan | nan         |       nan |        nan | complete               |         nan |                nan |              36 |      nan |                   36 | nan            | S123642             | Payment        | 2008-08-19 00:00:00+00:00 |    316378 |          85100 |
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+
# Sample in rs_unpaid and initial_source_log
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity    |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense |   lastSent | lifecycle:transition   |   matricola |   notificationType |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name   | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------|
# | 492695 | S74441    | Create Fine |        820 | 2002-07-30 00:00:00+00:00 | Variant 3 |               3 |       65 |       143 | NIL         |       nan |        nan | complete               |         nan |                nan |             nan |        0 |                    0 | A              | S74441              | Create Fine    | 2002-07-30 00:00:00+00:00 |    492695 |         133803 |
# | 492696 | S74441    | Send Fine   |        nan | 2002-09-12 00:00:00+00:00 | Variant 3 |               3 |      nan |       nan | nan         |        10 |        nan | complete               |         nan |                nan |             nan |      nan |                  nan | nan            | S74441              | Send Fine      | 2002-09-12 00:00:00+00:00 |    492696 |         133803 |
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+

# %% [markdown]
# We see that the number of unpaid cases is quite high, covering a bit more than half of the cases.\
# From the summary, we see that the attribute _TotalPaymentAmount_ consistently equals to 0 across all entries in the summary statistics, confirming that the lack of a _Payment_ activity correlates with a _TotalPaymentAmount_ = 0. This can be explained by the fact that _TotalPaymentAmount_ is an event attribute of _Payment_.\
#
# But did we include already all the cases with _totalPaymentAmount = 0_ with our query "unpaid"?

# %% [markdown]
# We decide to check how many of the cases we selected are actually not paid, i.e., they have a totalPaymentAmount = 0 in the result set and compare it with the original log as a reference.\
# To do so, we define the following property 'isNotPaid' as a predicate and characterize our result set based on the extent to which this property holds on it.

# %%
from logview.interfaces import Predicate

class isNotPaid(Predicate):

    def evaluate(self, log: pd.DataFrame) -> pd.DataFrame:
        case_id_glue = 'case:concept:name'

        # Get the maximum value of the amount paid by the offender
        max_totalPaymentAmount = log.groupby(case_id_glue)['totalPaymentAmount'].max()

        to_check = pd.concat([max_totalPaymentAmount], axis=1)

        # A fine is not paid if max(totalPaymentAmount) = 0
        unpaid_fines = to_check[to_check['totalPaymentAmount'] <= 0]
        case_id_to_keep = unpaid_fines['totalPaymentAmount'].index
        return log[log[case_id_glue].isin(case_id_to_keep)]

    def as_string(self) -> str:
        return 'max(totalPaymentAmount) <= 0'

# %% [markdown]
# We find out that our initial query was pretty accurate: apparently there is only one case that has activity _Payment_ and results in a _TotalPaymentAmount_ of 0.\
# This case can be easily retrieved from the complement set of our our result set.

# %% [markdown]
# We first label this result set as the set of unpaid cases, leaving out the case with initial amount = 0.0.

# %%
log_view.label_result_set(rs_no_p, 'unpaid')
_ = log_view.get_summary()
# Out:
# +----+--------------------+---------+--------------+------------+
# |    | source_log         | query   | result_set   | labels     |
# |----+--------------------+---------+--------------+------------|
# |  0 | initial_source_log | unpaid  | rs_unpaid    | ['unpaid'] |
# +----+--------------------+---------+--------------+------------+
# +----+---------+---------------------------------+
# |    | query   | predicates                      |
# |----+---------+---------------------------------|
# |  0 | unpaid  | (Activity not in { 'Payment' }) |
# +----+---------+---------------------------------+

# %%
from logview.result_set_characterizer.properties_evaluator import PropertiesEvaluator

# We instantiate the property evaluator plugin with our new property using our extension mechanisms and the dedicated "attach" method.
_ = log_view.attach_result_set_characterizer('property_evaluator', PropertiesEvaluator([isNotPaid()]))

# We characterize our result set and its complement with property 'isNotPaid' to see whether we left something out
_ = log_view.characterize_result_set_with_reference_log('rs_unpaid', complement_no_p, characterizer_name='property_evaluator')
# Out:
# +------------------------------+--------------+------------------------+
# |                              | rs_unpaid    | complement_rs_unpaid   |
# |------------------------------+--------------+------------------------|
# | max(totalPaymentAmount) <= 0 | (80655, 1.0) | (1, 0.0)               |
# +------------------------------+--------------+------------------------+

# %% [markdown]
# We can directly query for that case by adding our property as a new predicate to a query and querying the complement set of _rs_unpaid_.

# %%
query_p_unpaid = Query('p_not_paid', [isNotPaid()])
rs_not_p_unpaid, complement_rs_p_unpaid = log_view.evaluate_query('rs_p_unpaid', complement_no_p, query_p_unpaid)
log_view.label_result_set(rs_not_p_unpaid, 'unpaid')

rs_not_p_unpaid.head(10)
# Out:
#       Case ID     Activity Resource        Complete Timestamp     Variant  \
# 83199  C12623  Create Fine      811 2000-10-11 00:00:00+00:00  Variant 12
# 83200  C12623      Payment      NaN 2001-01-01 00:00:00+00:00  Variant 12
# 83201  C12623    Send Fine      NaN 2001-02-02 00:00:00+00:00  Variant 12
#
#        Variant index  amount  article dismissal  expense  ...  \
# 83199             12     0.0    171.0       NIL      NaN  ...
# 83200             12     NaN      NaN       NaN      NaN  ...
# 83201             12     NaN      NaN       NaN     6.71  ...
#
#       notificationType paymentAmount points totalPaymentAmount  vehicleClass  \
# 83199              NaN           NaN    0.0                0.0             C
# 83200              NaN           0.0    NaN                0.0           NaN
# 83201              NaN           NaN    NaN                NaN           NaN
#
#        case:concept:name  concept:name            time:timestamp @@index  \
# 83199             C12623   Create Fine 2000-10-11 00:00:00+00:00   83199
# 83200             C12623       Payment 2001-01-01 00:00:00+00:00   83200
# 83201             C12623     Send Fine 2001-02-02 00:00:00+00:00   83201
#
#       @@case_index
# 83199        24273
# 83200        24273
# 83201        24273
#
# [3 rows x 23 columns]

# %% [markdown]
# By inspecting case **C12623** we see that the initial amount of the fine is set to 0.0.\
#  Still, there is a _Payment activity with a _PaymentAmount_ of 0.0 but then there is an expense of 6.71 euros added when the fine is sent. This can then be categorized as being paid partially if we consider the expense attribute. However it is quite unusual that the initial amount is set at 0.0 and we check this further.

# %% [markdown]
# We query for cases in the RTFM log that have an initial amount = 0.0.

# %%
query_amount_zero = Query('amount_zero', LessEqualToConstant('amount', 0.0))
rs_amount_zero, complement_amount_zero = log_view.evaluate_query('rs_amount_zero', log, query_amount_zero)
log_view.label_result_set(rs_amount_zero, 'src:log')

# %%
_ = log_view.characterize_result_set_with_reference_log('rs_amount_zero', log, characterizer_name='set-cardinality')
# Out:
# Number of case_id in rs_amount_zero: 36
# Number of case_id in initial_source_log: 150370

# %%
_ = log_view.characterize_result_set_with_reference_log('rs_amount_zero', log, characterizer_name='summary-statistics')
# Out:
# Summary statistics of rs_amount_zero
# +------+----------+-----------+-----------+-----------------+-----------+----------------------+
# |      |   amount |   article |   expense |   paymentAmount |    points |   totalPaymentAmount |
# |------+----------+-----------+-----------+-----------------+-----------+----------------------|
# | mean |        0 |  116.25   |  10.2573  |         42.7662 |  0.722222 |              11.3461 |
# | std  |        0 |   78.1107 |   6.70244 |         48.6659 |  2.3858   |              30.9195 |
# | min  |        0 |    7      |   0       |          0      |  0        |               0      |
# | max  |        0 |  218      |  26       |        186      | 10        |             186      |
# +------+----------+-----------+-----------+-----------------+-----------+----------------------+
# Summary statistics of initial_source_log
# +------+-----------+-----------+-----------+-----------------+------------+----------------------+
# |      |    amount |   article |   expense |   paymentAmount |     points |   totalPaymentAmount |
# |------+-----------+-----------+-----------+-----------------+------------+----------------------|
# | mean |   63.6817 |  113.247  |  11.949   |         46.41   |  0.0788788 |              17.8156 |
# | std  |   89.678  |   68.2195 |   4.02319 |         39.3456 |  0.577687  |              36.7794 |
# | min  |    0      |    7      |   0       |          0      |  0         |               0      |
# | max  | 8000      |  401      |  76       |       3975      | 10         |            4021      |
# +------+-----------+-----------+-----------+-----------------+------------+----------------------+

# %%
_ = log_view.characterize_result_set_with_reference_log('rs_amount_zero', log, characterizer_name='random-example-retriever')
# Out:
# Sample from initial_source_log
# +--------+-----------+----------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity                   |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense | lastSent   | lifecycle:transition   |   matricola | notificationType   |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name               | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+----------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------+---------------------------+-----------+----------------|
# | 554124 | V7040     | Create Fine                |         35 | 2001-03-14 00:00:00+00:00 | Variant 1 |               1 |    131.2 |       142 | NIL         |    nan    | nan        | complete               |         nan | nan                |             nan |        0 |                    0 | A              | V7040               | Create Fine                | 2001-03-14 00:00:00+00:00 |    554124 |         148686 |
# | 554125 | V7040     | Send Fine                  |        nan | 2001-05-17 00:00:00+00:00 | Variant 1 |               1 |    nan   |       nan | nan         |     11.88 | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | V7040               | Send Fine                  | 2001-05-17 00:00:00+00:00 |    554125 |         148686 |
# | 554126 | V7040     | Insert Fine Notification   |        nan | 2001-06-15 00:00:00+00:00 | Variant 1 |               1 |    nan   |       nan | nan         |    nan    | N          | complete               |         nan | P                  |             nan |      nan |                  nan | nan            | V7040               | Insert Fine Notification   | 2001-06-15 00:00:00+00:00 |    554126 |         148686 |
# | 554127 | V7040     | Add penalty                |        nan | 2001-08-14 00:00:00+00:00 | Variant 1 |               1 |    262.4 |       nan | nan         |    nan    | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | V7040               | Add penalty                | 2001-08-14 00:00:00+00:00 |    554127 |         148686 |
# | 554128 | V7040     | Send for Credit Collection |        nan | 2003-01-10 00:00:00+00:00 | Variant 1 |               1 |    nan   |       nan | nan         |    nan    | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | V7040               | Send for Credit Collection | 2003-01-10 00:00:00+00:00 |    554128 |         148686 |
# +--------+-----------+----------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------+---------------------------+-----------+----------------+
# Sample in rs_amount_zero and initial_source_log
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity    |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense |   lastSent | lifecycle:transition   |   matricola |   notificationType |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name   | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------|
# | 335185 | S134167   | Create Fine |         29 | 2009-03-11 00:00:00+00:00 | Variant 2 |               2 |        0 |        40 | NIL         |       nan |        nan | complete               |         nan |                nan |             nan |        0 |                    0 | A              | S134167             | Create Fine    | 2009-03-11 00:00:00+00:00 |    335185 |          90415 |
# | 335186 | S134167   | Payment     |        nan | 2009-03-13 00:00:00+00:00 | Variant 2 |               2 |      nan |       nan | nan         |       nan |        nan | complete               |         nan |                nan |              38 |      nan |                   38 | nan            | S134167             | Payment        | 2009-03-13 00:00:00+00:00 |    335186 |          90415 |
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+

# %% [markdown]
# From our check we find 36 such cases. By looking at the summary statistics and examples, we see that offender actually still pay some money.\
# However, cases such as **C12623** seem to indicate data quality issues, mistakes in the recording, or or a "clumsy" way to register only some extra amounts, such as
# those related to the expense.

# %% [markdown]
# Since the number of cases is small, we move on with our analysis on unpaid cases.\
# Before we go deeper into this set, we check for cases that have actually been paid.

# %%
# we briefly check the queries ran so far
_ = log_view.get_summary()
# Out:
# +----+----------------------+-------------+----------------+-------------+
# |    | source_log           | query       | result_set     | labels      |
# |----+----------------------+-------------+----------------+-------------|
# |  0 | initial_source_log   | unpaid      | rs_unpaid      | ['unpaid']  |
# |  1 | complement_rs_unpaid | p_not_paid  | rs_p_unpaid    | ['unpaid']  |
# |  2 | initial_source_log   | amount_zero | rs_amount_zero | ['src:log'] |
# +----+----------------------+-------------+----------------+-------------+
# +----+-------------+---------------------------------+
# |    | query       | predicates                      |
# |----+-------------+---------------------------------|
# |  0 | unpaid      | (Activity not in { 'Payment' }) |
# |  1 | p_not_paid  | max(totalPaymentAmount) <= 0    |
# |  2 | amount_zero | (amount <= 0.0)                 |
# +----+-------------+---------------------------------+

# %% [markdown]
# We check for cases that are fully paid, i.e., cases where totalPaymentAmount >= amount + penalty + expense.\
# These cases might include also situations where the offender pays more than the amount due.
#
# As the complement of _rs_unpaid_ might include cases that are not paid in full, we define a new property 'isFullyPaid' as follows and add it to a new query.

# %%
from logview.interfaces import Predicate

class isFullyPaid(Predicate):

    def evaluate(self, log: pd.DataFrame) -> pd.DataFrame:
        case_id_glue = 'case:concept:name'

        # Get the maxium value of attribute amount to include the penalty
        max_amount = log.groupby(case_id_glue)['amount'].max()
        # Get the sum of all postal expenses
        sum_expenses = log.groupby(case_id_glue)['expense'].sum()
        # Get the maximum value of the amount paid by the offender
        max_totalPaymentAmount = log.groupby(case_id_glue)['totalPaymentAmount'].max()

        to_check = pd.concat([max_amount, sum_expenses, max_totalPaymentAmount], axis=1)

        # A fine is paid as long as max(amount) + sum(expense) <= max(totalPaymentAmount)
        paid_fines = to_check[to_check['amount'] + to_check['expense'] <= to_check['totalPaymentAmount']]
        case_id_to_keep = paid_fines['amount'].index
        return log[log[case_id_glue].isin(case_id_to_keep)]

    def as_string(self) -> str:
        return 'max(amount) + sum(expense) <= max(totalPaymentAmount)'

# %%
query_fully_paid = Query('fully_paid', [isFullyPaid()])
rs_fully_paid, complement_fully_paid = log_view.evaluate_query('rs_fully_paid', log, query_fully_paid)

rs_fully_paid.head(10)
# Out:
#    Case ID                  Activity Resource        Complete Timestamp  \
# 7   A10000               Create Fine      561 2007-03-09 00:00:00+00:00
# 8   A10000                 Send Fine      NaN 2007-07-17 00:00:00+00:00
# 9   A10000  Insert Fine Notification      NaN 2007-08-02 00:00:00+00:00
# 10  A10000               Add penalty      NaN 2007-10-01 00:00:00+00:00
# 11  A10000                   Payment      NaN 2008-09-09 00:00:00+00:00
# 23  A10005               Create Fine      537 2007-03-20 00:00:00+00:00
# 24  A10005                   Payment      NaN 2007-03-21 00:00:00+00:00
# 25  A10007               Create Fine      537 2007-03-20 00:00:00+00:00
# 26  A10007                   Payment      NaN 2007-03-23 00:00:00+00:00
# 32  A10009               Create Fine      537 2007-03-20 00:00:00+00:00
#
#       Variant  Variant index  amount  article dismissal  expense  ...  \
# 7   Variant 4              4    36.0    157.0       NIL      NaN  ...
# 8   Variant 4              4     NaN      NaN       NaN     13.0  ...
# 9   Variant 4              4     NaN      NaN       NaN      NaN  ...
# 10  Variant 4              4    74.0      NaN       NaN      NaN  ...
# 11  Variant 4              4     NaN      NaN       NaN      NaN  ...
# 23  Variant 2              2    36.0    157.0       NIL      NaN  ...
# 24  Variant 2              2     NaN      NaN       NaN      NaN  ...
# 25  Variant 2              2    36.0    157.0       NIL      NaN  ...
# 26  Variant 2              2     NaN      NaN       NaN      NaN  ...
# 32  Variant 5              5    22.0      7.0       NIL      NaN  ...
#
#    notificationType paymentAmount points totalPaymentAmount  vehicleClass  \
# 7               NaN           NaN    0.0                0.0             A
# 8               NaN           NaN    NaN                NaN           NaN
# 9                 P           NaN    NaN                NaN           NaN
# 10              NaN           NaN    NaN                NaN           NaN
# 11              NaN          87.0    NaN               87.0           NaN
# 23              NaN           NaN    0.0                0.0             A
# 24              NaN          36.0    NaN               36.0           NaN
# 25              NaN           NaN    0.0                0.0             A
# 26              NaN          36.0    NaN               36.0           NaN
# 32              NaN           NaN    0.0                0.0             A
#
#     case:concept:name              concept:name            time:timestamp  \
# 7              A10000               Create Fine 2007-03-09 00:00:00+00:00
# 8              A10000                 Send Fine 2007-07-17 00:00:00+00:00
# 9              A10000  Insert Fine Notification 2007-08-02 00:00:00+00:00
# 10             A10000               Add penalty 2007-10-01 00:00:00+00:00
# 11             A10000                   Payment 2008-09-09 00:00:00+00:00
# 23             A10005               Create Fine 2007-03-20 00:00:00+00:00
# 24             A10005                   Payment 2007-03-21 00:00:00+00:00
# 25             A10007               Create Fine 2007-03-20 00:00:00+00:00
# 26             A10007                   Payment 2007-03-23 00:00:00+00:00
# 32             A10009               Create Fine 2007-03-20 00:00:00+00:00
#
#    @@index @@case_index
# 7        7            2
# 8        8            2
# 9        9            2
# 10      10            2
# 11      11            2
# 23      23            5
# 24      24            5
# 25      25            6
# 26      26            6
# 32      32            8
#
# [10 rows x 23 columns]

# %%
log_view.label_result_set(rs_fully_paid, 'src:log')
log_view.label_result_set(rs_fully_paid, 'fully_paid')

# %% [markdown]
# We characterize this result set by comparison with the one of unpaid cases.

# %%
_ = log_view.characterize_result_set_with_reference_log('rs_fully_paid', rs_no_p, characterizer_name='*')
# Out:
# Number of case_id in rs_fully_paid: 60247
# Number of case_id in rs_unpaid: 80655
# +------------------------------+-----------------+--------------+
# |                              | rs_fully_paid   | rs_unpaid    |
# |------------------------------+-----------------+--------------|
# | max(totalPaymentAmount) <= 0 | (3, 0.0)        | (80655, 1.0) |
# +------------------------------+-----------------+--------------+
# Sample from rs_fully_paid
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity    |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense |   lastSent | lifecycle:transition   |   matricola |   notificationType |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name   | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------|
# | 305340 | S116790   | Create Fine |         49 | 2006-12-02 00:00:00+00:00 | Variant 7 |               7 |       35 |         7 | NIL         |       nan |        nan | complete               |         nan |                nan |             nan |        0 |                    0 | A              | S116790             | Create Fine    | 2006-12-02 00:00:00+00:00 |    305340 |          81966 |
# | 305341 | S116790   | Send Fine   |        nan | 2007-04-04 00:00:00+00:00 | Variant 7 |               7 |      nan |       nan | nan         |        11 |        nan | complete               |         nan |                nan |             nan |      nan |                  nan | nan            | S116790             | Send Fine      | 2007-04-04 00:00:00+00:00 |    305341 |          81966 |
# | 305342 | S116790   | Payment     |        nan | 2007-06-20 00:00:00+00:00 | Variant 7 |               7 |      nan |       nan | nan         |       nan |        nan | complete               |         nan |                nan |              46 |      nan |                   46 | nan            | S116790             | Payment        | 2007-06-20 00:00:00+00:00 |    305342 |          81966 |
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+
# Sample from rs_unpaid
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity    |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense |   lastSent | lifecycle:transition   |   matricola |   notificationType |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name   | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------|
# | 347854 | S140741   | Create Fine |         40 | 2009-07-25 00:00:00+00:00 | Variant 3 |               3 |       78 |       158 | NIL         |     nan   |        nan | complete               |         nan |                nan |             nan |        0 |                    0 | A              | S140741             | Create Fine    | 2009-07-25 00:00:00+00:00 |    347854 |          94004 |
# | 347855 | S140741   | Send Fine   |        nan | 2009-12-09 00:00:00+00:00 | Variant 3 |               3 |      nan |       nan | nan         |      13.5 |        nan | complete               |         nan |                nan |             nan |      nan |                  nan | nan            | S140741             | Send Fine      | 2009-12-09 00:00:00+00:00 |    347855 |          94004 |
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+
# Sample in rs_fully_paid and rs_unpaid
# +-------+-----------+----------------------------+------------+---------------------------+------------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------+---------------------------+-----------+----------------+
# |       | Case ID   | Activity                   |   Resource | Complete Timestamp        | Variant    |   Variant index |   amount |   article | dismissal   |   expense |   lastSent | lifecycle:transition   |   matricola | notificationType   |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name               | time:timestamp            |   @@index |   @@case_index |
# |-------+-----------+----------------------------+------------+---------------------------+------------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------+---------------------------+-----------+----------------|
# | 83374 | C12749    | Create Fine                |        807 | 2000-09-02 00:00:00+00:00 | Variant 17 |              17 |        0 |       192 | NIL         |       nan |        nan | complete               |         nan | nan                |             nan |        0 |                    0 | A              | C12749              | Create Fine                | 2000-09-02 00:00:00+00:00 |     83374 |          24309 |
# | 83375 | C12749    | Send Fine                  |        nan | 2000-09-02 00:00:00+00:00 | Variant 17 |              17 |      nan |       nan | nan         |         0 |        nan | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | C12749              | Send Fine                  | 2000-09-02 00:00:00+00:00 |     83375 |          24309 |
# | 83376 | C12749    | Insert Fine Notification   |        nan | 2000-09-02 00:00:00+00:00 | Variant 17 |              17 |      nan |       nan | nan         |       nan |        nan | complete               |         nan | P                  |             nan |      nan |                  nan | nan            | C12749              | Insert Fine Notification   | 2000-09-02 00:00:00+00:00 |     83376 |          24309 |
# | 83377 | C12749    | Appeal to Judge            |          0 | 2000-09-20 00:00:00+00:00 | Variant 17 |              17 |      nan |       nan | NIL         |       nan |        nan | complete               |           0 | nan                |             nan |      nan |                  nan | nan            | C12749              | Appeal to Judge            | 2000-09-20 00:00:00+00:00 |     83377 |          24309 |
# | 83378 | C12749    | Add penalty                |        nan | 2000-11-01 00:00:00+00:00 | Variant 17 |              17 |        0 |       nan | nan         |       nan |        nan | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | C12749              | Add penalty                | 2000-11-01 00:00:00+00:00 |     83378 |          24309 |
# | 83379 | C12749    | Send for Credit Collection |        nan | 2004-12-25 00:00:00+00:00 | Variant 17 |              17 |      nan |       nan | nan         |       nan |        nan | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | C12749              | Send for Credit Collection | 2004-12-25 00:00:00+00:00 |     83379 |          24309 |
# +-------+-----------+----------------------------+------------+---------------------------+------------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------+---------------------------+-----------+----------------+
# Summary statistics of rs_fully_paid
# +------+-----------+-----------+-----------+-----------------+------------+----------------------+
# |      |    amount |   article |   expense |   paymentAmount |     points |   totalPaymentAmount |
# |------+-----------+-----------+-----------+-----------------+------------+----------------------|
# | mean |   46.4372 |  110.125  |  11.7572  |         46.9415 |  0.0261092 |              26.1149 |
# | std  |   35.6948 |   69.7078 |   3.66075 |         37.5109 |  0.336553  |              39.7562 |
# | min  |    0      |    7      |   0       |          0      |  0         |               0      |
# | max  | 1597      |  401      |  45       |       3975      | 10         |            4021      |
# +------+-----------+-----------+-----------+-----------------+------------+----------------------+
# Summary statistics of rs_unpaid
# +------+-----------+-----------+-----------+-----------------+-----------+----------------------+
# |      |    amount |   article |   expense |   paymentAmount |    points |   totalPaymentAmount |
# |------+-----------+-----------+-----------+-----------------+-----------+----------------------|
# | mean |   71.1022 |   115.269 |  11.9872  |             nan |  0.121691 |                    0 |
# | std  |  105.518  |    67.287 |   4.04768 |             nan |  0.714412 |                    0 |
# | min  |    0      |     7     |   0       |             nan |  0        |                    0 |
# | max  | 8000      |   401     |  76       |             nan | 10        |                    0 |
# +------+-----------+-----------+-----------+-----------------+-----------+----------------------+

# %% [markdown]
# On this set, we decide to also check how main cases are actually paid exactly and how many are overpaid.
# We found that about 97% of the cases are paid exactly, while in 1634 cases offenders pay more than they should.

# %%
from logview.interfaces import Predicate

class isExactlyPaid(Predicate):

    def evaluate(self, log: pd.DataFrame) -> pd.DataFrame:
        case_id_glue = 'case:concept:name'

        # Get the maxium value of attribute amount to include the penalty
        max_amount = log.groupby(case_id_glue)['amount'].max()
        # Get the sum of all postal expenses
        sum_expenses = log.groupby(case_id_glue)['expense'].sum()
        # Get the maximum value of the amount paid by the offender
        max_totalPaymentAmount = log.groupby(case_id_glue)['totalPaymentAmount'].max()

        to_check = pd.concat([max_amount, sum_expenses, max_totalPaymentAmount], axis=1)

        # A fine is paid as long as max(amount) + sum(expense) <= max(totalPaymentAmount)
        paid_fines = to_check[to_check['amount'] + to_check['expense'] == to_check['totalPaymentAmount']]
        case_id_to_keep = paid_fines['amount'].index
        return log[log[case_id_glue].isin(case_id_to_keep)]

    def as_string(self) -> str:
        return 'max(amount) + sum(expense) == max(totalPaymentAmount)'

# %%
from logview.result_set_characterizer import PropertiesEvaluator
log_view.attach_result_set_characterizer('property_evaluator', PropertiesEvaluator([isExactlyPaid()]))

# %%
_ = log_view.characterize_result_set_with_reference_log('rs_fully_paid', log, characterizer_name='property_evaluator')
# Out:
# +-------------------------------------------------------+-----------------+----------------------+
# |                                                       | rs_fully_paid   | initial_source_log   |
# |-------------------------------------------------------+-----------------+----------------------|
# | max(amount) + sum(expense) == max(totalPaymentAmount) | (58613, 0.973)  | (58613, 0.39)        |
# +-------------------------------------------------------+-----------------+----------------------+

# %%
_ = log_view.characterize_result_set_with_reference_log('rs_fully_paid', log, characterizer_name='set-cardinality')
# Out:
# Number of case_id in rs_fully_paid: 60247
# Number of case_id in initial_source_log: 150370

# %% [markdown]
# Our example strategies also anticipates that the two result sets _unpaid_ and _fully_paid_ have actually some cases in common.\
# We then use the _Two Result Set Comparator_ component to look deeper into their relationships.

# %%
_ = log_view.compare_two_result_sets('rs_fully_paid', 'rs_unpaid')
# Out:
# Result set comparison between q: 'rs_fully_paid' and r: 'rs_unpaid'
#
# Intersection Matrix:
# +-----------+----------------------+
# |           |   Intersection Count |
# |-----------+----------------------|
# | q and r   |                    3 |
# | q and !r  |                60244 |
# | !q and r  |                80652 |
# | !q and !r |                 9471 |
# +-----------+----------------------+
#
# Analysis Context:
# 	Query from initial log to common ancestor 'initial_source_log':
# 	Queries from common ancestor to 'rs_fully_paid': max(amount) + sum(expense) <= max(totalPaymentAmount)
# 	Queries from common ancestor to 'rs_unpaid': (Activity not in { 'Payment' })
#
# Query Dependency Probability:
#  query_q --> query_r with 0.005 % query_r --> query_q with 0.004 %

# %% [markdown]
# From the matrix, we see to directions to further explore:
# 1)  9471 cases are neither fully paid nor unpaid. Could they be partially paid?
# 2) 3 cases that do not have Payment but are fully paid. Are these cases part of the _amount_zero_ cases?

# %% [markdown]
# We briefly check the second hypothesis, as the checking is immediate, and we find that this is true in 15 cases.

# %%
_ = log_view.compare_two_result_sets(rs_fully_paid, rs_amount_zero)
# Out:
# Result set comparison between q: 'rs_fully_paid' and r: 'rs_amount_zero'
#
# Intersection Matrix:
# +-----------+----------------------+
# |           |   Intersection Count |
# |-----------+----------------------|
# | q and r   |                   15 |
# | q and !r  |                60232 |
# | !q and r  |                   21 |
# | !q and !r |                90102 |
# +-----------+----------------------+
#
# Analysis Context:
# 	Query from initial log to common ancestor 'initial_source_log':
# 	Queries from common ancestor to 'rs_fully_paid': max(amount) + sum(expense) <= max(totalPaymentAmount)
# 	Queries from common ancestor to 'rs_amount_zero': (amount <= 0.0)
#
# Query Dependency Probability:
#  query_q --> query_r with 0.025 % query_r --> query_q with 41.667 %

# %% [markdown]
# We then take the result set !q and !r by defining a new _partially paid_ predicate by combining the two queries as follows: `0 < TotalPaymentAmount<max(amount) + expense`

# %%
class IsPartiallyPaid(Predicate):

    def evaluate(self, log: pd.DataFrame) -> pd.DataFrame:
        case_id_glue = 'case:concept:name'

        max_amount = log.groupby(case_id_glue)['amount'].max()
        sum_expenses = log.groupby(case_id_glue)['expense'].sum()
        max_totalPaymentAmount = log.groupby(case_id_glue)['totalPaymentAmount'].max()

        to_check = pd.concat([max_amount, sum_expenses, max_totalPaymentAmount], axis=1)

        # a fine is paid as long as max(amount) + sum(expense) <= max(totalPaymentAmount)
        partially_paid_fines = to_check[(to_check['amount'] + to_check['expense'] > (to_check['totalPaymentAmount'])) & (to_check['totalPaymentAmount'] > 0) ]
        case_id_to_keep = partially_paid_fines['amount'].index
        return log[log[case_id_glue].isin(case_id_to_keep)]

    def as_string(self) -> str:
        return 'max(amount) + sum(expense) > (max(totalPaymentAmount))'
    
query_partially_paid = Query('partially_paid', IsPartiallyPaid())
rs_is_partially_paid, complement_is_partially_paid = log_view.evaluate_query('rs_is_partially_paid', log, query_partially_paid)

# %%
log_view.label_result_set(rs_is_partially_paid, 'src:log')
log_view.label_result_set(rs_is_partially_paid, 'partially_paid')

# %%
_ = log_view.get_summary()
# Out:
# +----+----------------------+----------------+----------------------+-------------------------------+
# |    | source_log           | query          | result_set           | labels                        |
# |----+----------------------+----------------+----------------------+-------------------------------|
# |  0 | initial_source_log   | unpaid         | rs_unpaid            | ['unpaid']                    |
# |  1 | complement_rs_unpaid | p_not_paid     | rs_p_unpaid          | ['unpaid']                    |
# |  2 | initial_source_log   | amount_zero    | rs_amount_zero       | ['src:log']                   |
# |  3 | initial_source_log   | fully_paid     | rs_fully_paid        | ['src:log', 'fully_paid']     |
# |  4 | initial_source_log   | partially_paid | rs_is_partially_paid | ['src:log', 'partially_paid'] |
# +----+----------------------+----------------+----------------------+-------------------------------+
# +----+----------------+--------------------------------------------------------+
# |    | query          | predicates                                             |
# |----+----------------+--------------------------------------------------------|
# |  0 | unpaid         | (Activity not in { 'Payment' })                        |
# |  1 | p_not_paid     | max(totalPaymentAmount) <= 0                           |
# |  2 | amount_zero    | (amount <= 0.0)                                        |
# |  3 | fully_paid     | max(amount) + sum(expense) <= max(totalPaymentAmount)  |
# |  4 | partially_paid | max(amount) + sum(expense) > (max(totalPaymentAmount)) |
# +----+----------------+--------------------------------------------------------+

# %%
log_view.compare_result_sets(['rs_unpaid', 'rs_is_partially_paid', 'rs_fully_paid'])
# Out:
# +----+----------------+--------------------------------------------------------+
# |    | query name     | predicates                                             |
# |----+----------------+--------------------------------------------------------|
# |  0 | unpaid         | (Activity not in { 'Payment' })                        |
# |  1 | partially_paid | max(amount) + sum(expense) > (max(totalPaymentAmount)) |
# |  2 | fully_paid     | max(amount) + sum(expense) <= max(totalPaymentAmount)  |
# +----+----------------+--------------------------------------------------------+

# %% [markdown]
# We then decide to continue our exploration of _unpaid_ cases by using the union of partially paid and unpaid cases.\
# This can be taken with a property or by directly taking the complement set of _fully paid_ cases.

# %%
class isPartiallyPaidOrUnPaid(Predicate):

    def evaluate(self, log: pd.DataFrame) -> pd.DataFrame:
        case_id_glue = 'case:concept:name'

        # Get the maxium value of attribute amount to include the penalty
        max_amount = log.groupby(case_id_glue)['amount'].max()
        # Get the sum of all postal expenses
        sum_expenses = log.groupby(case_id_glue)['expense'].sum()
        # Get the maximum value of the amount paid by the offender
        max_totalPaymentAmount = log.groupby(case_id_glue)['totalPaymentAmount'].max()

        to_check = pd.concat([max_amount, sum_expenses, max_totalPaymentAmount], axis=1)

        # A fine is paid as long as max(amount) + sum(expense) > max(totalPaymentAmount)
        partially_or_unpaid_fines = to_check[to_check['amount'] + to_check['expense'] > to_check['totalPaymentAmount']]
        case_id_to_keep = partially_or_unpaid_fines['amount'].index
        return log[log[case_id_glue].isin(case_id_to_keep)]

    def as_string(self) -> str:
        return 'max(amount) + sum(expense) > max(totalPaymentAmount)'
    
query_is_partially_or_unpaid = Query('unpaid_or_partially', isPartiallyPaidOrUnPaid())
rs_is_partially_or_unpaid, complement_is_partially_or_unpaid = log_view.evaluate_query('unpaid_or_partially', log, query_is_partially_or_unpaid)
log_view.label_result_set(rs_is_partially_or_unpaid, 'unpaid or partially')
_ = log_view.characterize_result_set_with_reference_log(rs_is_partially_or_unpaid, complement_is_partially_or_unpaid, characterizer_name='set-cardinality')
# Out:
# Number of case_id in unpaid_or_partially: 90123
# Number of case_id in complement_unpaid_or_partially: 60247

# %% [markdown]
# We check for normative outcomes of the process, which we learned from the documentation. In these situations the offender is entitled not to pay.

# %% [markdown]
# This query aims to identify cases that have been sent for Credit Collection. In our process, such actions are taken for both unpaid cases and those partially paid. Sending cases for credit collection signifies the initiation of measures to recover outstanding amounts owed by offenders.

# %%
_ = log_view.attach_result_set_characterizer('property_evaluator', PropertiesEvaluator([isNotPaid()]))

# %%
query_scc = Query('sent_credit_collection', EqToConstant('Activity', 'Send for Credit Collection'))
rs_scc, complement_scc = log_view.evaluate_query('rs_scc', rs_is_partially_or_unpaid, query_scc)
log_view.label_result_set(rs_scc, 'unpaid or partially')

# %%
_ =log_view.characterize_result_set_with_reference_log(rs_scc, rs_is_partially_or_unpaid, characterizer_name='*')
# Out:
# Number of case_id in rs_scc: 59010
# Number of case_id in unpaid_or_partially: 90123
# +------------------------------+----------------+-----------------------+
# |                              | rs_scc         | unpaid_or_partially   |
# |------------------------------+----------------+-----------------------|
# | max(totalPaymentAmount) <= 0 | (56886, 0.964) | (80653, 0.895)        |
# +------------------------------+----------------+-----------------------+
# Sample from unpaid_or_partially
# +--------+-----------+----------------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity                         |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense | lastSent   | lifecycle:transition   |   matricola | notificationType   |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name                     | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+----------------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------------+---------------------------+-----------+----------------|
# | 404165 | S170358   | Create Fine                      |        852 | 2011-07-06 00:00:00+00:00 | Variant 8 |               8 |     39   |         7 | NIL         |       nan | nan        | complete               |         nan | nan                |             nan |        0 |                    0 | A              | S170358             | Create Fine                      | 2011-07-06 00:00:00+00:00 |    404165 |         109535 |
# | 404166 | S170358   | Send Fine                        |        nan | 2011-08-27 00:00:00+00:00 | Variant 8 |               8 |    nan   |       nan | nan         |        15 | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S170358             | Send Fine                        | 2011-08-27 00:00:00+00:00 |    404166 |         109535 |
# | 404167 | S170358   | Insert Fine Notification         |        nan | 2011-09-29 00:00:00+00:00 | Variant 8 |               8 |    nan   |       nan | nan         |       nan | P          | complete               |         nan | P                  |             nan |      nan |                  nan | nan            | S170358             | Insert Fine Notification         | 2011-09-29 00:00:00+00:00 |    404167 |         109535 |
# | 404168 | S170358   | Insert Date Appeal to Prefecture |        nan | 2011-09-30 00:00:00+00:00 | Variant 8 |               8 |    nan   |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S170358             | Insert Date Appeal to Prefecture | 2011-09-30 00:00:00+00:00 |    404168 |         109535 |
# | 404169 | S170358   | Add penalty                      |        nan | 2011-11-28 00:00:00+00:00 | Variant 8 |               8 |     79.5 |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S170358             | Add penalty                      | 2011-11-28 00:00:00+00:00 |    404169 |         109535 |
# | 404170 | S170358   | Send Appeal to Prefecture        |        nan | 2011-11-29 00:00:00+00:00 | Variant 8 |               8 |    nan   |       nan | #           |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S170358             | Send Appeal to Prefecture        | 2011-11-29 00:00:00+00:00 |    404170 |         109535 |
# +--------+-----------+----------------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------------+---------------------------+-----------+----------------+
# Sample in rs_scc and unpaid_or_partially
# +-------+-----------+----------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------+---------------------------+-----------+----------------+
# |       | Case ID   | Activity                   |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense | lastSent   | lifecycle:transition   |   matricola | notificationType   |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name               | time:timestamp            |   @@index |   @@case_index |
# |-------+-----------+----------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------+---------------------------+-----------+----------------|
# | 44988 | A31883    | Create Fine                |        563 | 2008-07-29 00:00:00+00:00 | Variant 1 |               1 |       36 |       157 | NIL         |     nan   | nan        | complete               |         nan | nan                |             nan |        0 |                    0 | A              | A31883              | Create Fine                | 2008-07-29 00:00:00+00:00 |     44988 |          12938 |
# | 44989 | A31883    | Send Fine                  |        nan | 2008-10-21 00:00:00+00:00 | Variant 1 |               1 |      nan |       nan | nan         |      13.5 | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | A31883              | Send Fine                  | 2008-10-21 00:00:00+00:00 |     44989 |          12938 |
# | 44990 | A31883    | Insert Fine Notification   |        nan | 2008-10-28 00:00:00+00:00 | Variant 1 |               1 |      nan |       nan | nan         |     nan   | P          | complete               |         nan | P                  |             nan |      nan |                  nan | nan            | A31883              | Insert Fine Notification   | 2008-10-28 00:00:00+00:00 |     44990 |          12938 |
# | 44991 | A31883    | Add penalty                |        nan | 2008-12-27 00:00:00+00:00 | Variant 1 |               1 |       74 |       nan | nan         |     nan   | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | A31883              | Add penalty                | 2008-12-27 00:00:00+00:00 |     44991 |          12938 |
# | 44992 | A31883    | Send for Credit Collection |        nan | 2010-10-15 00:00:00+00:00 | Variant 1 |               1 |      nan |       nan | nan         |     nan   | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | A31883              | Send for Credit Collection | 2010-10-15 00:00:00+00:00 |     44992 |          12938 |
# +-------+-----------+----------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------+---------------------------+-----------+----------------+
# Summary statistics of rs_scc
# +------+----------+-----------+-----------+-----------------+-----------+----------------------+
# |      |   amount |   article |   expense |   paymentAmount |    points |   totalPaymentAmount |
# |------+----------+-----------+-----------+-----------------+-----------+----------------------|
# | mean |   74.132 |  115.232  |  11.7317  |         53.5153 |  0.124572 |              1.93065 |
# | std  |  106.638 |   67.1682 |   4.02616 |         40.0556 |  0.719824 |             12.7683  |
# | min  |   18.78  |    7      |   0       |          1.32   |  0        |              0       |
# | max  | 8000     |  401      |  60       |        727      | 10        |            727       |
# +------+----------+-----------+-----------+-----------------+-----------+----------------------+
# Summary statistics of unpaid_or_partially
# +------+-----------+-----------+-----------+-----------------+-----------+----------------------+
# |      |    amount |   article |   expense |   paymentAmount |    points |   totalPaymentAmount |
# |------+-----------+-----------+-----------+-----------------+-----------+----------------------|
# | mean |   71.3983 |  115.334  |  11.9786  |         43.8581 |  0.114155 |              7.83455 |
# | std  |  104.298  |   67.1256 |   4.07555 |         47.0893 |  0.691369 |             29.9379  |
# | min  |    0      |    7      |   0       |          0      |  0        |              0       |
# | max  | 8000      |  401      |  76       |       1064      | 10        |           1842       |
# +------+-----------+-----------+-----------+-----------------+-----------+----------------------+

# %% [markdown]
# We then want to check for dependencies among queries, to see if unpaid cases correlate with cases sent for credit collection.\
# We will use our set _unpaid_or_partially_ and our set _rs_scc_ and compare them.

# %%
log_view.compare_two_result_sets(rs_is_partially_or_unpaid,rs_scc)
# Out:
# Result set comparison between q: 'unpaid_or_partially' and r: 'rs_scc'
#
# Intersection Matrix:
# +-----------+----------------------+
# |           |   Intersection Count |
# |-----------+----------------------|
# | q and r   |                59010 |
# | q and !r  |                31113 |
# | !q and r  |                    0 |
# | !q and !r |                    0 |
# +-----------+----------------------+
#
# Analysis Context:
# 	Query from initial log to common ancestor 'unpaid_or_partially': max(amount) + sum(expense) > max(totalPaymentAmount)
# 	Queries from common ancestor to 'unpaid_or_partially':
# 	Queries from common ancestor to 'rs_scc': (Activity in { 'Send for Credit Collection' })
#
# Query Dependency Probability:
#  query_q --> query_r with 65.477 % query_r --> query_q with 100.000 %
# {'intersection-matrix': {'analysis_context': {'query_common_ancestor': <logview.predicate.query.Query at 0x20ede0f7c50>,
#    'query_q': <logview.predicate.query.Query at 0x20e81877650>,
#    'query_r': <logview.predicate.query.Query at 0x20e81877b00>},
#   'intersection_matrix':            Intersection Count
#   q and r                 59010
#   q and !r                31113
#   !q and r                    0
#   !q and !r                   0,
#   'result_set_positioning': 'query_q --> query_r with 65.477 % query_r --> query_q with 100.000 %'}}

# %% [markdown]
# The results show clearly that _rs_scc_ is a subset of _unpaid_or_partially_ and that we have 31113 that are not sent for credit collection.\
# Excluding the small amount of cases with initial amount at 0.0, we still have a large number of cases to characterize.
#
# Let's briefly compare the cases sent for credit collection with the set of unpaid cases we found at the beginning, i.e., we leave out partial payments.
# We see from the result that query (Activity not in { 'Payment' }) implies query (Activity in { 'Send for Credit Collection' }) and max(amount) + sum(expense) > max(totalPaymentAmount) with a probability of 96.4%, meaning that most of the cases that are sent for credit collection are actually unpaid cases.
#
# Partially paid cases may be treated differently.

# %%
log_view.compare_two_result_sets(rs_no_p, rs_scc)
# Out:
# Result set comparison between q: 'rs_unpaid' and r: 'rs_scc'
#
# Intersection Matrix:
# +-----------+----------------------+
# |           |   Intersection Count |
# |-----------+----------------------|
# | q and r   |                56886 |
# | q and !r  |                23769 |
# | !q and r  |                 2124 |
# | !q and !r |                67591 |
# +-----------+----------------------+
#
# Analysis Context:
# 	Query from initial log to common ancestor 'initial_source_log':
# 	Queries from common ancestor to 'rs_unpaid': (Activity not in { 'Payment' })
# 	Queries from common ancestor to 'rs_scc': (Activity in { 'Send for Credit Collection' }) and max(amount) + sum(expense) > max(totalPaymentAmount)
#
# Query Dependency Probability:
#  query_q --> query_r with 70.530 % query_r --> query_q with 96.401 %
# {'intersection-matrix': {'analysis_context': {'query_common_ancestor': <logview.predicate.query.Query at 0x20ede0f66c0>,
#    'query_q': <logview.predicate.query.Query at 0x20ede0f40b0>,
#    'query_r': <logview.predicate.query.Query at 0x20ede0f50d0>},
#   'intersection_matrix':            Intersection Count
#   q and r                 56886
#   q and !r                23769
#   !q and r                 2124
#   !q and !r               67591,
#   'result_set_positioning': 'query_q --> query_r with 70.530 % query_r --> query_q with 96.401 %'}}

# %% [markdown]
# This query targets cases concluding with the issuance of fines, specifically those ending with *Send Fine*.\
# According to our documented process, if fines are not created and sent within 90 days, offenders are not obliged to pay. Here we start checking for cases ending with Send Fine

# %%
query_ends_with_send_fine = Query('ends_with_send_fine', EndWith('Send Fine'))
rs_ends_with_send_fine, complement_ends_with_send_fine = log_view.evaluate_query('rs_ends_with_send_fine', rs_is_partially_or_unpaid, query_ends_with_send_fine)
log_view.label_result_set(rs_ends_with_send_fine, 'unpaid or partially')

# %%
_ =log_view.characterize_result_set_with_reference_log(rs_ends_with_send_fine, rs_is_partially_or_unpaid, characterizer_name='*')
# Out:
# Number of case_id in rs_ends_with_send_fine: 20736
# Number of case_id in unpaid_or_partially: 90123
# +------------------------------+--------------------------+-----------------------+
# |                              | rs_ends_with_send_fine   | unpaid_or_partially   |
# |------------------------------+--------------------------+-----------------------|
# | max(totalPaymentAmount) <= 0 | (20393, 0.983)           | (80653, 0.895)        |
# +------------------------------+--------------------------+-----------------------+
# Sample from unpaid_or_partially
# +-------+-----------+----------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------+---------------------------+-----------+----------------+
# |       | Case ID   | Activity                   |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense | lastSent   | lifecycle:transition   |   matricola | notificationType   |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name               | time:timestamp            |   @@index |   @@case_index |
# |-------+-----------+----------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------+---------------------------+-----------+----------------|
# | 25401 | A21950    | Create Fine                |        541 | 2007-09-24 00:00:00+00:00 | Variant 1 |               1 |       36 |       157 | NIL         |       nan | nan        | complete               |         nan | nan                |             nan |        0 |                    0 | A              | A21950              | Create Fine                | 2007-09-24 00:00:00+00:00 |     25401 |           7208 |
# | 25402 | A21950    | Send Fine                  |        nan | 2008-01-18 00:00:00+00:00 | Variant 1 |               1 |      nan |       nan | nan         |        13 | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | A21950              | Send Fine                  | 2008-01-18 00:00:00+00:00 |     25402 |           7208 |
# | 25403 | A21950    | Insert Fine Notification   |        nan | 2008-01-30 00:00:00+00:00 | Variant 1 |               1 |      nan |       nan | nan         |       nan | P          | complete               |         nan | P                  |             nan |      nan |                  nan | nan            | A21950              | Insert Fine Notification   | 2008-01-30 00:00:00+00:00 |     25403 |           7208 |
# | 25404 | A21950    | Add penalty                |        nan | 2008-03-30 00:00:00+00:00 | Variant 1 |               1 |       74 |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | A21950              | Add penalty                | 2008-03-30 00:00:00+00:00 |     25404 |           7208 |
# | 25405 | A21950    | Send for Credit Collection |        nan | 2009-03-30 00:00:00+00:00 | Variant 1 |               1 |      nan |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | A21950              | Send for Credit Collection | 2009-03-30 00:00:00+00:00 |     25405 |           7208 |
# +-------+-----------+----------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------------------+---------------------------+-----------+----------------+
# Sample in rs_ends_with_send_fine and unpaid_or_partially
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity    |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense |   lastSent | lifecycle:transition   |   matricola |   notificationType |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name   | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------|
# | 441500 | S51456    | Create Fine |        820 | 2000-05-30 00:00:00+00:00 | Variant 3 |               3 |     31.3 |       157 | NIL         |    nan    |        nan | complete               |         nan |                nan |             nan |        0 |                    0 | A              | S51456              | Create Fine    | 2000-05-30 00:00:00+00:00 |    441500 |         120477 |
# | 441501 | S51456    | Send Fine   |        nan | 2000-07-28 00:00:00+00:00 | Variant 3 |               3 |    nan   |       nan | nan         |      6.46 |        nan | complete               |         nan |                nan |             nan |      nan |                  nan | nan            | S51456              | Send Fine      | 2000-07-28 00:00:00+00:00 |    441501 |         120477 |
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+
# Summary statistics of rs_ends_with_send_fine
# +------+----------+-----------+-----------+-----------------+------------+----------------------+
# |      |   amount |   article |   expense |   paymentAmount |     points |   totalPaymentAmount |
# |------+----------+-----------+-----------+-----------------+------------+----------------------|
# | mean |  43.8336 |  115.122  |  12.4808  |         36.1766 |  0.0509742 |             0.590358 |
# | std  |  45.2718 |   67.7896 |   3.78701 |         12.8928 |  0.463322  |             4.86975  |
# | min  |   0      |    7      |   0       |          0      |  0         |             0        |
# | max  | 798      |  401      |  76       |        159      | 10         |           159        |
# +------+----------+-----------+-----------+-----------------+------------+----------------------+
# Summary statistics of unpaid_or_partially
# +------+-----------+-----------+-----------+-----------------+-----------+----------------------+
# |      |    amount |   article |   expense |   paymentAmount |    points |   totalPaymentAmount |
# |------+-----------+-----------+-----------+-----------------+-----------+----------------------|
# | mean |   71.3983 |  115.334  |  11.9786  |         43.8581 |  0.114155 |              7.83455 |
# | std  |  104.298  |   67.1256 |   4.07555 |         47.0893 |  0.691369 |             29.9379  |
# | min  |    0      |    7      |   0       |          0      |  0        |              0       |
# | max  | 8000      |  401      |  76       |       1064      | 10        |           1842       |
# +------+-----------+-----------+-----------+-----------------+-----------+----------------------+

# %% [markdown]
# This query focuses on cases marked for dismissal, denoted by '#' (dismissal by the prefecture) or 'G' (dismissal by the judge).

# %%
query_dismissed = Query('dismissed', EqToConstant('dismissal', ['#', 'G']))
rs_dismissed, complement_dismissed = log_view.evaluate_query('rs_dismissed', rs_is_partially_or_unpaid, query_dismissed)
log_view.label_result_set(rs_dismissed, 'unpaid or partially')
log_view.label_result_set(rs_dismissed, 'src:unpaid_or_partially')

# %%
_ =log_view.characterize_result_set_with_reference_log(rs_dismissed, rs_is_partially_or_unpaid, characterizer_name='*')
# Out:
# Number of case_id in rs_dismissed: 2072
# Number of case_id in unpaid_or_partially: 90123
# +------------------------------+----------------+-----------------------+
# |                              | rs_dismissed   | unpaid_or_partially   |
# |------------------------------+----------------+-----------------------|
# | max(totalPaymentAmount) <= 0 | (2069, 0.999)  | (80653, 0.895)        |
# +------------------------------+----------------+-----------------------+
# Sample from unpaid_or_partially
# +-------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------+
# |       | Case ID   | Activity                 |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense | lastSent   | lifecycle:transition   |   matricola | notificationType   |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name             | time:timestamp            |   @@index |   @@case_index |
# |-------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------|
# | 91748 | C18068    | Create Fine              |         46 | 2005-07-20 00:00:00+00:00 | Variant 4 |               4 |    357   |       180 | NIL         |       nan | nan        | complete               |         nan | nan                |             nan |        0 |                    0 | A              | C18068              | Create Fine              | 2005-07-20 00:00:00+00:00 |     91748 |          26175 |
# | 91749 | C18068    | Send Fine                |        nan | 2005-07-20 00:00:00+00:00 | Variant 4 |               4 |    nan   |       nan | nan         |         0 | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | C18068              | Send Fine                | 2005-07-20 00:00:00+00:00 |     91749 |          26175 |
# | 91750 | C18068    | Insert Fine Notification |        nan | 2005-07-20 00:00:00+00:00 | Variant 4 |               4 |    nan   |       nan | nan         |       nan | C          | complete               |         nan | P                  |             nan |      nan |                  nan | nan            | C18068              | Insert Fine Notification | 2005-07-20 00:00:00+00:00 |     91750 |          26175 |
# | 91751 | C18068    | Add penalty              |        nan | 2005-09-18 00:00:00+00:00 | Variant 4 |               4 |    716.5 |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | C18068              | Add penalty              | 2005-09-18 00:00:00+00:00 |     91751 |          26175 |
# | 91752 | C18068    | Payment                  |        nan | 2005-09-19 00:00:00+00:00 | Variant 4 |               4 |    nan   |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             357 |      nan |                  357 | nan            | C18068              | Payment                  | 2005-09-19 00:00:00+00:00 |     91752 |          26175 |
# +-------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------+
# Sample in rs_dismissed and unpaid_or_partially
# +--------+-----------+---------------------------------------+------------+---------------------------+------------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+---------------------------------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity                              |   Resource | Complete Timestamp        | Variant    |   Variant index |   amount |   article | dismissal   |   expense | lastSent   | lifecycle:transition   |   matricola | notificationType   |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name                          | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+---------------------------------------+------------+---------------------------+------------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+---------------------------------------+---------------------------+-----------+----------------|
# | 373354 | S154222   | Create Fine                           |        852 | 2010-06-21 00:00:00+00:00 | Variant 33 |              33 |     38   |         7 | NIL         |       nan | nan        | complete               |         nan | nan                |             nan |        0 |                    0 | A              | S154222             | Create Fine                           | 2010-06-21 00:00:00+00:00 |    373354 |         101214 |
# | 373355 | S154222   | Send Fine                             |        nan | 2010-09-09 00:00:00+00:00 | Variant 33 |              33 |    nan   |       nan | nan         |        26 | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S154222             | Send Fine                             | 2010-09-09 00:00:00+00:00 |    373355 |         101214 |
# | 373356 | S154222   | Insert Fine Notification              |        nan | 2010-09-16 00:00:00+00:00 | Variant 33 |              33 |    nan   |       nan | nan         |       nan | P          | complete               |         nan | P                  |             nan |      nan |                  nan | nan            | S154222             | Insert Fine Notification              | 2010-09-16 00:00:00+00:00 |    373356 |         101214 |
# | 373357 | S154222   | Add penalty                           |        nan | 2010-11-15 00:00:00+00:00 | Variant 33 |              33 |     77.5 |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S154222             | Add penalty                           | 2010-11-15 00:00:00+00:00 |    373357 |         101214 |
# | 373358 | S154222   | Insert Date Appeal to Prefecture      |        nan | 2010-11-18 00:00:00+00:00 | Variant 33 |              33 |    nan   |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S154222             | Insert Date Appeal to Prefecture      | 2010-11-18 00:00:00+00:00 |    373358 |         101214 |
# | 373359 | S154222   | Send Appeal to Prefecture             |        nan | 2011-01-11 00:00:00+00:00 | Variant 33 |              33 |    nan   |       nan | #           |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S154222             | Send Appeal to Prefecture             | 2011-01-11 00:00:00+00:00 |    373359 |         101214 |
# | 373360 | S154222   | Receive Result Appeal from Prefecture |        nan | 2011-02-22 00:00:00+00:00 | Variant 33 |              33 |    nan   |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S154222             | Receive Result Appeal from Prefecture | 2011-02-22 00:00:00+00:00 |    373360 |         101214 |
# | 373361 | S154222   | Notify Result Appeal to Offender      |        nan | 2011-03-03 00:00:00+00:00 | Variant 33 |              33 |    nan   |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S154222             | Notify Result Appeal to Offender      | 2011-03-03 00:00:00+00:00 |    373361 |         101214 |
# +--------+-----------+---------------------------------------+------------+---------------------------+------------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+---------------------------------------+---------------------------+-----------+----------------+
# Summary statistics of rs_dismissed
# +------+-----------+-----------+-----------+-----------------+----------+----------------------+
# |      |    amount |   article |   expense |   paymentAmount |   points |   totalPaymentAmount |
# |------+-----------+-----------+-----------+-----------------+----------+----------------------|
# | mean |   94.9657 |  116.95   |  12.8995  |        115.167  |  0.54778 |             0.166506 |
# | std  |  173.983  |   65.8648 |   4.04145 |         35.5117 |  1.40827 |             4.51371  |
# | min  |    0      |    7      |   0       |         91.5    |  0       |             0        |
# | max  | 8000      |  401      |  35       |        156      | 10       |           156        |
# +------+-----------+-----------+-----------+-----------------+----------+----------------------+
# Summary statistics of unpaid_or_partially
# +------+-----------+-----------+-----------+-----------------+-----------+----------------------+
# |      |    amount |   article |   expense |   paymentAmount |    points |   totalPaymentAmount |
# |------+-----------+-----------+-----------+-----------------+-----------+----------------------|
# | mean |   71.3983 |  115.334  |  11.9786  |         43.8581 |  0.114155 |              7.83455 |
# | std  |  104.298  |   67.1256 |   4.07555 |         47.0893 |  0.691369 |             29.9379  |
# | min  |    0      |    7      |   0       |          0      |  0        |              0       |
# | max  | 8000      |  401      |  76       |       1064      | 10        |           1842       |
# +------+-----------+-----------+-----------+-----------------+-----------+----------------------+

# %% [markdown]
# We then decide to plot the main result sets we obtained by analyzing the unpaid_or_partially set. To do so, we use the label 'unpaid or partially', which we gave to all the result sets having these payment outcomes.
# The UpSet plot shows the result sets ordered by cardinality and the proportion of the result sets where the query predicates hold alone or in overlap.

# %%
log_view.compare_result_sets_with_label('unpaid or partially')
# Out:
# +----+------------------------+------------------------------------------------------+
# |    | query name             | predicates                                           |
# |----+------------------------+------------------------------------------------------|
# |  0 | unpaid_or_partially    | max(amount) + sum(expense) > max(totalPaymentAmount) |
# |  1 | sent_credit_collection | (Activity in { 'Send for Credit Collection' })       |
# |  2 | ends_with_send_fine    | (EndWith { 'Send Fine' })                            |
# |  3 | dismissed              | (dismissal in { '#', 'G' })                          |
# +----+------------------------+------------------------------------------------------+

# %% [markdown]
# From the plot, we see that 8309 cases in the unpaid or partially paid set are not covered by the normative outcomes we checked for.\
# These might be cases where offenders actually needed to pay but did not. We then go deep into this set of cases, which we call _R_.

# %%
# take the union of the three subqueries
union_queries = Query("union_queries", Union([query_scc, query_ends_with_send_fine, query_dismissed]))
# derive the result set and the complement
union_queries, R = log_view.evaluate_query('union_queries', rs_is_partially_or_unpaid, union_queries)
# check the cardinality of the complement to ensure it matches the UpSet Plot
_ = log_view.characterize_result_set_with_reference_log(union_queries, R, characterizer_name='set-cardinality')
# Out:
# Number of case_id in union_queries: 81814
# Number of case_id in complement_union_queries: 8309

# %% [markdown]
# We checked the normative constraint of 90 days between Create Fine and Send Fine, discovering that 47% of the cases in _R_ do not observe it.

# %%
class DistanceBetweenEvents(Predicate):

    def __init__(self, activity_a: str, activity_b: str, seconds: int):
        self.activity_a = activity_a
        self.activity_b = activity_b
        self.seconds = seconds

    def evaluate(self, log: pd.DataFrame) -> pd.DataFrame:
        return pm4py.filter_paths_performance(log, (self.activity_a, self.activity_b), 0, self.seconds)

    def as_string(self) -> str:
        return f'{self.activity_a} <--> {self.activity_b} with {self.seconds}'

# %%
query_90_days = Query('90_days_constraint', DistanceBetweenEvents('Create Fine', 'Send Fine', 90 * 86400))
rs_90_days, complement_90_days = log_view.evaluate_query('rs_90_days', R, query_90_days)
log_view.label_result_set(rs_90_days, label='src:R')

rs_90_days.head(20)
# Out:
#      Case ID                  Activity Resource        Complete Timestamp  \
# 1364  A10581               Create Fine      557 2007-05-27 00:00:00+00:00
# 1365  A10581                 Send Fine      NaN 2007-08-20 00:00:00+00:00
# 1366  A10581  Insert Fine Notification      NaN 2007-08-29 00:00:00+00:00
# 1367  A10581               Add penalty      NaN 2007-10-28 00:00:00+00:00
# 1368  A10581                   Payment      NaN 2007-10-31 00:00:00+00:00
# 3745  A11664               Create Fine      537 2007-05-01 00:00:00+00:00
# 3746  A11664                 Send Fine      NaN 2007-07-17 00:00:00+00:00
# 3747  A11664  Insert Fine Notification      NaN 2007-07-24 00:00:00+00:00
# 3748  A11664               Add penalty      NaN 2007-09-22 00:00:00+00:00
# 3749  A11664                   Payment      NaN 2007-09-24 00:00:00+00:00
# 4633  A12078               Create Fine      557 2007-05-06 00:00:00+00:00
# 4634  A12078                 Send Fine      NaN 2007-07-17 00:00:00+00:00
# 4635  A12078  Insert Fine Notification      NaN 2007-07-24 00:00:00+00:00
# 4636  A12078               Add penalty      NaN 2007-09-22 00:00:00+00:00
# 4637  A12078                   Payment      NaN 2007-09-24 00:00:00+00:00
# 4706  A12115               Create Fine      557 2007-05-10 00:00:00+00:00
# 4707  A12115                 Send Fine      NaN 2007-07-17 00:00:00+00:00
# 4708  A12115  Insert Fine Notification      NaN 2007-07-24 00:00:00+00:00
# 4709  A12115               Add penalty      NaN 2007-09-22 00:00:00+00:00
# 4710  A12115                   Payment      NaN 2007-09-22 00:00:00+00:00
#
#         Variant  Variant index  amount  article dismissal  expense  ...  \
# 1364  Variant 4              4    22.0      7.0       NIL      NaN  ...
# 1365  Variant 4              4     NaN      NaN       NaN     13.0  ...
# 1366  Variant 4              4     NaN      NaN       NaN      NaN  ...
# 1367  Variant 4              4    44.0      NaN       NaN      NaN  ...
# 1368  Variant 4              4     NaN      NaN       NaN      NaN  ...
# 3745  Variant 4              4    36.0    157.0       NIL      NaN  ...
# 3746  Variant 4              4     NaN      NaN       NaN     13.0  ...
# 3747  Variant 4              4     NaN      NaN       NaN      NaN  ...
# 3748  Variant 4              4    74.0      NaN       NaN      NaN  ...
# 3749  Variant 4              4     NaN      NaN       NaN      NaN  ...
# 4633  Variant 4              4    36.0    157.0       NIL      NaN  ...
# 4634  Variant 4              4     NaN      NaN       NaN     13.0  ...
# 4635  Variant 4              4     NaN      NaN       NaN      NaN  ...
# 4636  Variant 4              4    74.0      NaN       NaN      NaN  ...
# 4637  Variant 4              4     NaN      NaN       NaN      NaN  ...
# 4706  Variant 4              4    36.0    157.0       NIL      NaN  ...
# 4707  Variant 4              4     NaN      NaN       NaN     13.0  ...
# 4708  Variant 4              4     NaN      NaN       NaN      NaN  ...
# 4709  Variant 4              4    74.0      NaN       NaN      NaN  ...
# 4710  Variant 4              4     NaN      NaN       NaN      NaN  ...
#
#      notificationType paymentAmount points totalPaymentAmount  vehicleClass  \
# 1364              NaN           NaN    0.0                0.0             A
# 1365              NaN           NaN    NaN                NaN           NaN
# 1366                P           NaN    NaN                NaN           NaN
# 1367              NaN           NaN    NaN                NaN           NaN
# 1368              NaN          35.0    NaN               35.0           NaN
# 3745              NaN           NaN    0.0                0.0             A
# 3746              NaN           NaN    NaN                NaN           NaN
# 3747                P           NaN    NaN                NaN           NaN
# 3748              NaN           NaN    NaN                NaN           NaN
# 3749              NaN          49.0    NaN               49.0           NaN
# 4633              NaN           NaN    0.0                0.0             A
# 4634              NaN           NaN    NaN                NaN           NaN
# 4635                P           NaN    NaN                NaN           NaN
# 4636              NaN           NaN    NaN                NaN           NaN
# 4637              NaN          49.0    NaN               49.0           NaN
# 4706              NaN           NaN    0.0                0.0             A
# 4707              NaN           NaN    NaN                NaN           NaN
# 4708                P           NaN    NaN                NaN           NaN
# 4709              NaN           NaN    NaN                NaN           NaN
# 4710              NaN          49.0    NaN               49.0           NaN
#
#       case:concept:name              concept:name            time:timestamp  \
# 1364             A10581               Create Fine 2007-05-27 00:00:00+00:00
# 1365             A10581                 Send Fine 2007-08-20 00:00:00+00:00
# 1366             A10581  Insert Fine Notification 2007-08-29 00:00:00+00:00
# 1367             A10581               Add penalty 2007-10-28 00:00:00+00:00
# 1368             A10581                   Payment 2007-10-31 00:00:00+00:00
# 3745             A11664               Create Fine 2007-05-01 00:00:00+00:00
# 3746             A11664                 Send Fine 2007-07-17 00:00:00+00:00
# 3747             A11664  Insert Fine Notification 2007-07-24 00:00:00+00:00
# 3748             A11664               Add penalty 2007-09-22 00:00:00+00:00
# 3749             A11664                   Payment 2007-09-24 00:00:00+00:00
# 4633             A12078               Create Fine 2007-05-06 00:00:00+00:00
# 4634             A12078                 Send Fine 2007-07-17 00:00:00+00:00
# 4635             A12078  Insert Fine Notification 2007-07-24 00:00:00+00:00
# 4636             A12078               Add penalty 2007-09-22 00:00:00+00:00
# 4637             A12078                   Payment 2007-09-24 00:00:00+00:00
# 4706             A12115               Create Fine 2007-05-10 00:00:00+00:00
# 4707             A12115                 Send Fine 2007-07-17 00:00:00+00:00
# 4708             A12115  Insert Fine Notification 2007-07-24 00:00:00+00:00
# 4709             A12115               Add penalty 2007-09-22 00:00:00+00:00
# 4710             A12115                   Payment 2007-09-22 00:00:00+00:00
#
#      @@index @@case_index
# 1364    1364          381
# 1365    1365          381
# 1366    1366          381
# 1367    1367          381
# 1368    1368          381
# 3745    3745         1097
# 3746    3746         1097
# 3747    3747         1097
# 3748    3748         1097
# 3749    3749         1097
# 4633    4633         1358
# 4634    4634         1358
# 4635    4635         1358
# 4636    4636         1358
# 4637    4637         1358
# 4706    4706         1381
# 4707    4707         1381
# 4708    4708         1381
# 4709    4709         1381
# 4710    4710         1381
#
# [20 rows x 23 columns]

# %%
_ = log_view.characterize_result_set_with_reference_log(rs_90_days, R, characterizer_name='set-cardinality')

log_view.attach_result_set_characterizer('property_evaluator', PropertiesEvaluator([DistanceBetweenEvents('Create Fine', 'Send Fine', 90 * 86400)]))
_ = log_view.characterize_result_set_with_reference_log(R, rs_is_partially_or_unpaid, characterizer_name='property_evaluator')
# Out:
# Number of case_id in rs_90_days: 4381
# Number of case_id in complement_union_queries: 8309
# +-----------------------------------------+----------------------------+-----------------------+
# |                                         | complement_union_queries   | unpaid_or_partially   |
# |-----------------------------------------+----------------------------+-----------------------|
# | Create Fine <--> Send Fine with 7776000 | (4381, 0.527)              | (46841, 0.52)         |
# +-----------------------------------------+----------------------------+-----------------------+

# %% [markdown]
# We check the same property on the entire log (divided into _fully paid_ cases and _unpaid_or_partially_ paid ones), to have an estimate of cases in which the offender might not need to pay their fines.

# %%
log_view.attach_result_set_characterizer('property_evaluator', PropertiesEvaluator([DistanceBetweenEvents('Create Fine', 'Send Fine', 90 * 86400)]))
_ = log_view.characterize_result_set_with_reference_log(rs_is_partially_or_unpaid, rs_fully_paid, characterizer_name='property_evaluator')
# Out:
# +-----------------------------------------+-----------------------+-----------------+
# |                                         | unpaid_or_partially   | rs_fully_paid   |
# |-----------------------------------------+-----------------------+-----------------|
# | Create Fine <--> Send Fine with 7776000 | (46841, 0.52)         | (6945, 0.115)   |
# +-----------------------------------------+-----------------------+-----------------+

# %% [markdown]
# We continue with characterizing R, adjusting the payment threshold, and leaving a tolerance of 10 Euros for offenders to pay their fines.

# %%
class IsPaidwithThreshold(Predicate):

    def evaluate(self, log: pd.DataFrame) -> pd.DataFrame:
        case_id_glue = 'case:concept:name'

        max_amount = log.groupby(case_id_glue)['amount'].max()
        sum_expenses = log.groupby(case_id_glue)['expense'].sum()
        max_totalPaymentAmount = log.groupby(case_id_glue)['totalPaymentAmount'].max()

        to_check = pd.concat([max_amount, sum_expenses, max_totalPaymentAmount], axis=1)

        # a fine is paid as long as max(amount) + sum(expense) <= max(totalPaymentAmount)
        paid_fines = to_check[to_check['amount'] + to_check['expense'] - 10 <= (to_check['totalPaymentAmount'])]
        case_id_to_keep = paid_fines['amount'].index
        return log[log[case_id_glue].isin(case_id_to_keep)]

    def as_string(self) -> str:
        return 'max(amount) + sum(expense) - 10 <= (max(totalPaymentAmount))'
    
query_threshold = Query('paid_within_10', [IsPaidwithThreshold()])
rs_within10, complement_within10 = log_view.evaluate_query('rs_paid_within_10', R, query_threshold)
log_view.label_result_set(rs_within10, label='src:R')

# %%
_ = log_view.characterize_result_set_with_reference_log(rs_within10, R, characterizer_name='*')
# Out:
# Number of case_id in rs_paid_within_10: 826
# Number of case_id in complement_union_queries: 8309
# +-----------------------------------------+---------------------+----------------------------+
# |                                         | rs_paid_within_10   | complement_union_queries   |
# |-----------------------------------------+---------------------+----------------------------|
# | Create Fine <--> Send Fine with 7776000 | (495, 0.599)        | (4381, 0.527)              |
# +-----------------------------------------+---------------------+----------------------------+
# Sample from complement_union_queries
# +--------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity                 |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense | lastSent   | lifecycle:transition   |   matricola | notificationType   |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name             | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------|
# | 553692 | V6842     | Create Fine              |         29 | 2000-10-16 00:00:00+00:00 | Variant 4 |               4 |   125.19 |       142 | NIL         |    nan    | nan        | complete               |         nan | nan                |           nan   |        0 |                  0   | A              | V6842               | Create Fine              | 2000-10-16 00:00:00+00:00 |    553692 |         148591 |
# | 553693 | V6842     | Send Fine                |        nan | 2000-11-30 00:00:00+00:00 | Variant 4 |               4 |   nan    |       nan | nan         |      6.71 | nan        | complete               |         nan | nan                |           nan   |      nan |                nan   | nan            | V6842               | Send Fine                | 2000-11-30 00:00:00+00:00 |    553693 |         148591 |
# | 553694 | V6842     | Insert Fine Notification |        nan | 2000-12-30 00:00:00+00:00 | Variant 4 |               4 |   nan    |       nan | nan         |    nan    | N          | complete               |         nan | P                  |           nan   |      nan |                nan   | nan            | V6842               | Insert Fine Notification | 2000-12-30 00:00:00+00:00 |    553694 |         148591 |
# | 553695 | V6842     | Add penalty              |        nan | 2001-02-28 00:00:00+00:00 | Variant 4 |               4 |   250.38 |       nan | nan         |    nan    | nan        | complete               |         nan | nan                |           nan   |      nan |                nan   | nan            | V6842               | Add penalty              | 2001-02-28 00:00:00+00:00 |    553695 |         148591 |
# | 553696 | V6842     | Payment                  |        nan | 2001-02-28 00:00:00+00:00 | Variant 4 |               4 |   nan    |       nan | nan         |    nan    | nan        | complete               |         nan | nan                |           131.9 |      nan |                131.9 | nan            | V6842               | Payment                  | 2001-02-28 00:00:00+00:00 |    553696 |         148591 |
# +--------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------+
# Sample in rs_paid_within_10 and complement_union_queries
# +--------+-----------+---------------------------------------+------------+---------------------------+------------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+---------------------------------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity                              |   Resource | Complete Timestamp        | Variant    |   Variant index |   amount |   article | dismissal   |   expense | lastSent   | lifecycle:transition   |   matricola | notificationType   |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name                          | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+---------------------------------------+------------+---------------------------+------------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+---------------------------------------+---------------------------+-----------+----------------|
# | 318832 | S124964   | Create Fine                           |         48 | 2008-06-13 00:00:00+00:00 | Variant 13 |              13 |       36 |       157 | NIL         |       nan | nan        | complete               |         nan | nan                |             nan |        0 |                    0 | A              | S124964             | Create Fine                           | 2008-06-13 00:00:00+00:00 |    318832 |          85764 |
# | 318833 | S124964   | Send Fine                             |        nan | 2008-07-30 00:00:00+00:00 | Variant 13 |              13 |      nan |       nan | nan         |        26 | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S124964             | Send Fine                             | 2008-07-30 00:00:00+00:00 |    318833 |          85764 |
# | 318834 | S124964   | Insert Fine Notification              |        nan | 2008-08-05 00:00:00+00:00 | Variant 13 |              13 |      nan |       nan | nan         |       nan | P          | complete               |         nan | P                  |             nan |      nan |                  nan | nan            | S124964             | Insert Fine Notification              | 2008-08-05 00:00:00+00:00 |    318834 |          85764 |
# | 318835 | S124964   | Insert Date Appeal to Prefecture      |        nan | 2008-09-09 00:00:00+00:00 | Variant 13 |              13 |      nan |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S124964             | Insert Date Appeal to Prefecture      | 2008-09-09 00:00:00+00:00 |    318835 |          85764 |
# | 318836 | S124964   | Add penalty                           |        nan | 2008-10-04 00:00:00+00:00 | Variant 13 |              13 |       74 |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S124964             | Add penalty                           | 2008-10-04 00:00:00+00:00 |    318836 |          85764 |
# | 318837 | S124964   | Send Appeal to Prefecture             |        nan | 2008-10-17 00:00:00+00:00 | Variant 13 |              13 |      nan |       nan | NIL         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S124964             | Send Appeal to Prefecture             | 2008-10-17 00:00:00+00:00 |    318837 |          85764 |
# | 318838 | S124964   | Receive Result Appeal from Prefecture |        nan | 2008-11-06 00:00:00+00:00 | Variant 13 |              13 |      nan |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S124964             | Receive Result Appeal from Prefecture | 2008-11-06 00:00:00+00:00 |    318838 |          85764 |
# | 318839 | S124964   | Notify Result Appeal to Offender      |        nan | 2008-11-14 00:00:00+00:00 | Variant 13 |              13 |      nan |       nan | nan         |       nan | nan        | complete               |         nan | nan                |             nan |      nan |                  nan | nan            | S124964             | Notify Result Appeal to Offender      | 2008-11-14 00:00:00+00:00 |    318839 |          85764 |
# | 318840 | S124964   | Payment                               |        nan | 2008-12-17 00:00:00+00:00 | Variant 13 |              13 |      nan |       nan | nan         |       nan | nan        | complete               |         nan | nan                |              98 |      nan |                   98 | nan            | S124964             | Payment                               | 2008-12-17 00:00:00+00:00 |    318840 |          85764 |
# +--------+-----------+---------------------------------------+------------+---------------------------+------------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+---------------------------------------+---------------------------+-----------+----------------+
# Summary statistics of rs_paid_within_10
# +------+----------+-----------+-----------+-----------------+----------+----------------------+
# |      |   amount |   article |   expense |   paymentAmount |   points |   totalPaymentAmount |
# |------+----------+-----------+-----------+-----------------+----------+----------------------|
# | mean |  68.902  |  110.953  |  13.3875  |         76.9756 | 0.062954 |              49.668  |
# | std  |  65.3816 |   67.6101 |   7.26396 |         58.5797 | 0.51725  |              72.9284 |
# | min  |  18.78   |    7      |   0       |         11      | 0        |               0      |
# | max  | 779.5    |  191      |  45       |        791.5    | 5        |             791.5    |
# +------+----------+-----------+-----------+-----------------+----------+----------------------+
# Summary statistics of complement_union_queries
# +------+----------+-----------+-----------+-----------------+------------+----------------------+
# |      |   amount |   article |   expense |   paymentAmount |     points |   totalPaymentAmount |
# |------+----------+-----------+-----------+-----------------+------------+----------------------|
# | mean |   80.825 |  116.169  |  12.2538  |         42.1645 |  0.0896618 |              35.4528 |
# | std  |  111.626 |   65.4579 |   4.89383 |         48.7841 |  0.645361  |              57.8832 |
# | min  |    0     |    7      |   0       |          0.2    |  0         |               0      |
# | max  | 3684.5   |  401      |  46       |       1064      | 10         |            1842      |
# +------+----------+-----------+-----------+-----------------+------------+----------------------+

# %% [markdown]
# At last, we continue examining these differences between paid amounts and actual amounts to pay with some selected properties, going deep into complements of the result sets that we cannot explain with the exsiting properties.

# %%
class OnlyFineAndExpense(Predicate):

    def evaluate(self, log: pd.DataFrame) -> pd.DataFrame:
        case_id_glue = 'case:concept:name'

        log = log[log['Activity'] != 'Add penalty']
        max_amount = log.groupby(case_id_glue)['amount'].max()
        sum_expenses = log.groupby(case_id_glue)['expense'].sum()
        max_totalPaymentAmount = log.groupby(case_id_glue)['totalPaymentAmount'].max()

        to_check = pd.concat([max_amount, sum_expenses, max_totalPaymentAmount], axis=1)

        # a fine is paid as long as max(amount) + sum(expense) <= max(totalPaymentAmount)
        paid_fines = to_check[to_check['amount'] + to_check['expense'] <= (to_check['totalPaymentAmount'])]
        case_id_to_keep = paid_fines['amount'].index
        return log[log[case_id_glue].isin(case_id_to_keep)]

    def as_string(self) -> str:
        return f'max(amount) + sum(expense) <= max(totalPaymentAmount)'


query_only_fine_and_expense = Query('only_fine_and_expense', OnlyFineAndExpense())
rs_only_fine_and_expense, complement_only_fine_and_expense = log_view.evaluate_query('rs_only_fine_and_expense', R, query_only_fine_and_expense)
log_view.label_result_set(rs_only_fine_and_expense, label='src:R')

# %%
_ = log_view.characterize_result_set_with_reference_log(rs_only_fine_and_expense, complement_only_fine_and_expense, characterizer_name='random-example-retriever')
_ = log_view.characterize_result_set_with_reference_log(rs_only_fine_and_expense, complement_only_fine_and_expense, characterizer_name='summary-statistics')
# Out:
# Sample from rs_only_fine_and_expense
# +--------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity                 |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense | lastSent   | lifecycle:transition   |   matricola | notificationType   |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name             | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------|
# | 216321 | N70127    | Create Fine              |        558 | 2005-01-16 00:00:00+00:00 | Variant 6 |               6 |       35 |       157 | NIL         |     nan   | nan        | complete               |         nan | nan                |           nan   |        0 |                  0   | A              | N70127              | Create Fine              | 2005-01-16 00:00:00+00:00 |    216321 |          56870 |
# | 216322 | N70127    | Send Fine                |        nan | 2005-06-10 00:00:00+00:00 | Variant 6 |               6 |      nan |       nan | nan         |      16.6 | nan        | complete               |         nan | nan                |           nan   |      nan |                nan   | nan            | N70127              | Send Fine                | 2005-06-10 00:00:00+00:00 |    216322 |          56870 |
# | 216323 | N70127    | Insert Fine Notification |        nan | 2005-06-25 00:00:00+00:00 | Variant 6 |               6 |      nan |       nan | nan         |     nan   | P          | complete               |         nan | P                  |           nan   |      nan |                nan   | nan            | N70127              | Insert Fine Notification | 2005-06-25 00:00:00+00:00 |    216323 |          56870 |
# | 216324 | N70127    | Payment                  |        nan | 2005-07-19 00:00:00+00:00 | Variant 6 |               6 |      nan |       nan | nan         |     nan   | nan        | complete               |         nan | nan                |            46   |      nan |                 46   | nan            | N70127              | Payment                  | 2005-07-19 00:00:00+00:00 |    216324 |          56870 |
# | 216326 | N70127    | Payment                  |        nan | 2005-08-25 00:00:00+00:00 | Variant 6 |               6 |      nan |       nan | nan         |     nan   | nan        | complete               |         nan | nan                |             5.6 |      nan |                 51.6 | nan            | N70127              | Payment                  | 2005-08-25 00:00:00+00:00 |    216326 |          56870 |
# +--------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------+
# Sample from complement_rs_only_fine_and_expense
# +--------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity                 |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense | lastSent   | lifecycle:transition   |   matricola | notificationType   |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name             | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------|
# | 131618 | N30242    | Create Fine              |        538 | 2000-12-13 00:00:00+00:00 | Variant 6 |               6 |    31.3  |       157 | NIL         |    nan    | nan        | complete               |         nan | nan                |          nan    |        0 |                 0    | A              | N30242              | Create Fine              | 2000-12-13 00:00:00+00:00 |    131618 |          35331 |
# | 131619 | N30242    | Send Fine                |        nan | 2001-02-16 00:00:00+00:00 | Variant 6 |               6 |   nan    |       nan | nan         |     11.88 | nan        | complete               |         nan | nan                |          nan    |      nan |               nan    | nan            | N30242              | Send Fine                | 2001-02-16 00:00:00+00:00 |    131619 |          35331 |
# | 131620 | N30242    | Insert Fine Notification |        nan | 2001-03-01 00:00:00+00:00 | Variant 6 |               6 |   nan    |       nan | nan         |    nan    | N          | complete               |         nan | P                  |          nan    |      nan |               nan    | nan            | N30242              | Insert Fine Notification | 2001-03-01 00:00:00+00:00 |    131620 |          35331 |
# | 131621 | N30242    | Payment                  |        nan | 2001-03-21 00:00:00+00:00 | Variant 6 |               6 |   nan    |       nan | nan         |    nan    | nan        | complete               |         nan | nan                |           38.01 |      nan |                38.01 | nan            | N30242              | Payment                  | 2001-03-21 00:00:00+00:00 |    131621 |          35331 |
# | 131622 | N30242    | Add penalty              |        nan | 2001-04-30 00:00:00+00:00 | Variant 6 |               6 |    62.59 |       nan | nan         |    nan    | nan        | complete               |         nan | nan                |          nan    |      nan |               nan    | nan            | N30242              | Add penalty              | 2001-04-30 00:00:00+00:00 |    131622 |          35331 |
# | 131623 | N30242    | Payment                  |        nan | 2001-05-29 00:00:00+00:00 | Variant 6 |               6 |   nan    |       nan | nan         |    nan    | nan        | complete               |         nan | nan                |            5.16 |      nan |                43.17 | nan            | N30242              | Payment                  | 2001-05-29 00:00:00+00:00 |    131623 |          35331 |
# +--------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------+
# Summary statistics of rs_only_fine_and_expense
# +------+-----------+-----------+-----------+-----------------+------------+----------------------+
# |      |    amount |   article |   expense |   paymentAmount |     points |   totalPaymentAmount |
# |------+-----------+-----------+-----------+-----------------+------------+----------------------|
# | mean |   50.5861 |  117.081  |   12.3311 |         43.3341 |  0.0432233 |              39.3947 |
# | std  |   60.9169 |   65.0197 |    4.6393 |         50.7991 |  0.441415  |              62.1082 |
# | min  |   18.78   |    7      |    0      |          0.2    |  0         |               0      |
# | max  | 1842      |  193      |   45      |       1064      | 10         |            1842      |
# +------+-----------+-----------+-----------+-----------------+------------+----------------------+
# Summary statistics of complement_rs_only_fine_and_expense
# +------+-----------+-----------+-----------+-----------------+-----------+----------------------+
# |      |    amount |   article |   expense |   paymentAmount |    points |   totalPaymentAmount |
# |------+-----------+-----------+-----------+-----------------+-----------+----------------------|
# | mean |   93.1493 |  113.843  |  12.0517  |         35.0616 |  0.20812  |              19.8934 |
# | std  |  138.723  |   66.5201 |   5.49968 |         33.2176 |  0.981149 |              32.3487 |
# | min  |    0      |    7      |   0       |          1      |  0        |               0      |
# | max  | 2220      |  401      |  46       |        357      | 10        |             406.52   |
# +------+-----------+-----------+-----------+-----------------+-----------+----------------------+

# %%
class OnlyFine(Predicate):

    def evaluate(self, log: pd.DataFrame) -> pd.DataFrame:
        case_id_glue = 'case:concept:name'

        log = log[log['Activity'] != 'Add penalty']
        max_amount = log.groupby(case_id_glue)['amount'].max()
        max_totalPaymentAmount = log.groupby(case_id_glue)['totalPaymentAmount'].max()

        to_check = pd.concat([max_amount, max_totalPaymentAmount], axis=1)

        # a fine is paid as long as max(amount) <= max(totalPaymentAmount)
        paid_fines = to_check[to_check['amount'] <= (to_check['totalPaymentAmount'])]
        case_id_to_keep = paid_fines['amount'].index
        return log[log[case_id_glue].isin(case_id_to_keep)]

    def as_string(self) -> str:
        return f'max(amount) <= max(totalPaymentAmount)'
    
query_only_fine = Query('only_fine', OnlyFine())
rs_only_fine, complement_only_fine = log_view.evaluate_query('rs_only_fine', complement_only_fine_and_expense, query_only_fine)
_ = log_view.characterize_result_set_with_reference_log(rs_only_fine, complement_only_fine, characterizer_name='set-cardinality')
# Out:
# Number of case_id in rs_only_fine: 958
# Number of case_id in complement_rs_only_fine: 1382

# %%
_ = log_view.characterize_result_set_with_reference_log(rs_only_fine, complement_only_fine, characterizer_name='random-example-retriever')
# Out:
# Sample from rs_only_fine
# +--------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity                 |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense | lastSent   | lifecycle:transition   |   matricola | notificationType   |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name             | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------|
# | 132992 | N30721    | Create Fine              |        537 | 2000-12-22 00:00:00+00:00 | Variant 6 |               6 |     31.3 |       157 | NIL         |    nan    | nan        | complete               |         nan | nan                |          nan    |        0 |                 0    | A              | N30721              | Create Fine              | 2000-12-22 00:00:00+00:00 |    132992 |          35637 |
# | 132993 | N30721    | Send Fine                |        nan | 2001-02-16 00:00:00+00:00 | Variant 6 |               6 |    nan   |       nan | nan         |     11.88 | nan        | complete               |         nan | nan                |          nan    |      nan |               nan    | nan            | N30721              | Send Fine                | 2001-02-16 00:00:00+00:00 |    132993 |          35637 |
# | 132994 | N30721    | Insert Fine Notification |        nan | 2001-03-06 00:00:00+00:00 | Variant 6 |               6 |    nan   |       nan | nan         |    nan    | N          | complete               |         nan | P                  |          nan    |      nan |               nan    | nan            | N30721              | Insert Fine Notification | 2001-03-06 00:00:00+00:00 |    132994 |          35637 |
# | 132995 | N30721    | Payment                  |        nan | 2001-04-17 00:00:00+00:00 | Variant 6 |               6 |    nan   |       nan | nan         |    nan    | nan        | complete               |         nan | nan                |           38.01 |      nan |                38.01 | nan            | N30721              | Payment                  | 2001-04-17 00:00:00+00:00 |    132995 |          35637 |
# | 132997 | N30721    | Payment                  |        nan | 2001-05-21 00:00:00+00:00 | Variant 6 |               6 |    nan   |       nan | nan         |    nan    | nan        | complete               |         nan | nan                |            5.16 |      nan |                43.17 | nan            | N30721              | Payment                  | 2001-05-21 00:00:00+00:00 |    132997 |          35637 |
# +--------+-----------+--------------------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+--------------------------+---------------------------+-----------+----------------+
# Sample from complement_rs_only_fine
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+
# |        | Case ID   | Activity    |   Resource | Complete Timestamp        | Variant   |   Variant index |   amount |   article | dismissal   |   expense |   lastSent | lifecycle:transition   |   matricola |   notificationType |   paymentAmount |   points |   totalPaymentAmount | vehicleClass   | case:concept:name   | concept:name   | time:timestamp            |   @@index |   @@case_index |
# |--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------|
# | 182129 | N51249    | Create Fine |        537 | 2003-10-14 00:00:00+00:00 | Variant 2 |               2 |     33.6 |       157 | NIL         |       nan |        nan | complete               |         nan |                nan |           nan   |        0 |                  0   | A              | N51249              | Create Fine    | 2003-10-14 00:00:00+00:00 |    182129 |          47677 |
# | 182130 | N51249    | Payment     |        nan | 2003-10-20 00:00:00+00:00 | Variant 2 |               2 |    nan   |       nan | nan         |       nan |        nan | complete               |         nan |                nan |            33.5 |      nan |                 33.5 | nan            | N51249              | Payment        | 2003-10-20 00:00:00+00:00 |    182130 |          47677 |
# +--------+-----------+-------------+------------+---------------------------+-----------+-----------------+----------+-----------+-------------+-----------+------------+------------------------+-------------+--------------------+-----------------+----------+----------------------+----------------+---------------------+----------------+---------------------------+-----------+----------------+

# %%
class NeverPaid(Predicate):

    def evaluate(self, log: pd.DataFrame) -> pd.DataFrame:
        case_id_glue = 'case:concept:name'
        max_totalPaymentAmount = log.groupby(case_id_glue)['totalPaymentAmount'].max()
        to_check = pd.concat([max_totalPaymentAmount], axis=1)

        paid_fines = to_check[to_check['totalPaymentAmount'] == 0.0]
        case_id_to_keep = paid_fines['totalPaymentAmount'].index
        return log[log[case_id_glue].isin(case_id_to_keep)]

    def as_string(self) -> str:
        return f'max(totalPaymentAmount) == 0.0'

query_never_paid = Query('never_paid', NeverPaid())
rs_never_paid, complement_never_paid = log_view.evaluate_query('rs_never_paid', complement_only_fine, query_never_paid)
_ = log_view.characterize_result_set_with_reference_log(rs_never_paid, complement_never_paid, characterizer_name='set-cardinality')
# Out:
# Number of case_id in rs_never_paid: 1306
# Number of case_id in complement_rs_never_paid: 76

# %%
_ = log_view.get_summary()
# Out:
# +----+-------------------------------------+------------------------+--------------------------+----------------------------------------------------+
# |    | source_log                          | query                  | result_set               | labels                                             |
# |----+-------------------------------------+------------------------+--------------------------+----------------------------------------------------|
# |  0 | initial_source_log                  | unpaid                 | rs_unpaid                | ['unpaid']                                         |
# |  1 | complement_rs_unpaid                | p_not_paid             | rs_p_unpaid              | ['unpaid']                                         |
# |  2 | initial_source_log                  | amount_zero            | rs_amount_zero           | ['src:log']                                        |
# |  3 | initial_source_log                  | fully_paid             | rs_fully_paid            | ['src:log', 'fully_paid']                          |
# |  4 | initial_source_log                  | partially_paid         | rs_is_partially_paid     | ['src:log', 'partially_paid']                      |
# |  5 | initial_source_log                  | unpaid_or_partially    | unpaid_or_partially      | ['unpaid or partially']                            |
# |  6 | unpaid_or_partially                 | sent_credit_collection | rs_scc                   | ['unpaid or partially']                            |
# |  7 | unpaid_or_partially                 | ends_with_send_fine    | rs_ends_with_send_fine   | ['unpaid or partially']                            |
# |  8 | unpaid_or_partially                 | dismissed              | rs_dismissed             | ['unpaid or partially', 'src:unpaid_or_partially'] |
# |  9 | unpaid_or_partially                 | union_queries          | union_queries            | []                                                 |
# | 10 | complement_union_queries            | 90_days_constraint     | rs_90_days               | ['src:R']                                          |
# | 11 | complement_union_queries            | paid_within_10         | rs_paid_within_10        | ['src:R']                                          |
# | 12 | complement_union_queries            | only_fine_and_expense  | rs_only_fine_and_expense | ['src:R']                                          |
# | 13 | complement_rs_only_fine_and_expense | only_fine              | rs_only_fine             | []                                                 |
# | 14 | complement_rs_only_fine             | never_paid             | rs_never_paid            | []                                                 |
# +----+-------------------------------------+------------------------+--------------------------+----------------------------------------------------+
# +----+------------------------+------------------------------------------------------------------------------------------------------------+
# |    | query                  | predicates                                                                                                 |
# |----+------------------------+------------------------------------------------------------------------------------------------------------|
# |  0 | unpaid                 | (Activity not in { 'Payment' })                                                                            |
# |  1 | p_not_paid             | max(totalPaymentAmount) <= 0                                                                               |
# |  2 | amount_zero            | (amount <= 0.0)                                                                                            |
# |  3 | fully_paid             | max(amount) + sum(expense) <= max(totalPaymentAmount)                                                      |
# |  4 | partially_paid         | max(amount) + sum(expense) > (max(totalPaymentAmount))                                                     |
# |  5 | unpaid_or_partially    | max(amount) + sum(expense) > max(totalPaymentAmount)                                                       |
# |  6 | sent_credit_collection | (Activity in { 'Send for Credit Collection' })                                                             |
# |  7 | ends_with_send_fine    | (EndWith { 'Send Fine' })                                                                                  |
# |  8 | dismissed              | (dismissal in { '#', 'G' })                                                                                |
# |  9 | union_queries          | (Activity in { 'Send for Credit Collection' }) or (EndWith { 'Send Fine' }) or (dismissal in { '#', 'G' }) |
# | 10 | 90_days_constraint     | Create Fine <--> Send Fine with 7776000                                                                    |
# | 11 | paid_within_10         | max(amount) + sum(expense) - 10 <= (max(totalPaymentAmount))                                               |
# | 12 | only_fine_and_expense  | max(amount) + sum(expense) <= max(totalPaymentAmount)                                                      |
# | 13 | only_fine              | max(amount) <= max(totalPaymentAmount)                                                                     |
# | 14 | never_paid             | max(totalPaymentAmount) == 0.0                                                                             |
# +----+------------------------+------------------------------------------------------------------------------------------------------------+

# %%
log_view.compare_result_sets_with_label(requested_label='src:R')
# Out:
# +----+-----------------------+--------------------------------------------------------------+
# |    | query name            | predicates                                                   |
# |----+-----------------------+--------------------------------------------------------------|
# |  0 | 90_days_constraint    | Create Fine <--> Send Fine with 7776000                      |
# |  1 | paid_within_10        | max(amount) + sum(expense) - 10 <= (max(totalPaymentAmount)) |
# |  2 | only_fine_and_expense | max(amount) + sum(expense) <= max(totalPaymentAmount)        |
# +----+-----------------------+--------------------------------------------------------------+

# %%
log_view.characterize_result_set_with_reference_log(rs_never_paid, rs_only_fine_and_expense, characterizer_name='set-cardinality')
log_view.label_result_set(rs_never_paid, label='src:R')
# log_view.label_result_set(complement_never_paid, label='src:R')
# Out:
# Number of case_id in rs_never_paid: 1306
# Number of case_id in rs_only_fine_and_expense: 5969

# %%
log_view.compare_result_sets_with_label(requested_label='src:R')
# Out:
# +----+-----------------------+--------------------------------------------------------------+
# |    | query name            | predicates                                                   |
# |----+-----------------------+--------------------------------------------------------------|
# |  0 | 90_days_constraint    | Create Fine <--> Send Fine with 7776000                      |
# |  1 | paid_within_10        | max(amount) + sum(expense) - 10 <= (max(totalPaymentAmount)) |
# |  2 | only_fine_and_expense | max(amount) + sum(expense) <= max(totalPaymentAmount)        |
# |  3 | never_paid            | max(totalPaymentAmount) == 0.0                               |
# +----+-----------------------+--------------------------------------------------------------+

# %%
class ExceedingButStillPaid(Predicate):

    def evaluate(self, log: pd.DataFrame) -> pd.DataFrame:
        case_id_glue = 'case:concept:name'

        log = log[log['Activity'] != 'Add penalty']
        log_ = pm4py.filter_paths_performance(log, ('Create Fine', 'Send Fine'), 0, 90 * 86400)
        max_amount = log_.groupby(case_id_glue)['amount'].max()
        sum_expenses = log_.groupby(case_id_glue)['expense'].sum()
        max_totalPaymentAmount = log_.groupby(case_id_glue)['totalPaymentAmount'].max()
        to_check = pd.concat([max_amount, sum_expenses, max_totalPaymentAmount], axis=1)

        # a fine is paid as long as max(amount) + sum(expense) <= max(totalPaymentAmount)
        paid_fines = to_check[to_check['amount'] + to_check['expense'] <= (to_check['totalPaymentAmount'])]
        case_id_to_keep = paid_fines['amount'].index
        return log[log[case_id_glue].isin(case_id_to_keep)]

    def as_string(self) -> str:
        return f'max(totalPaymentAmount) == 0.0'

query_never_paid = Query('never_paid', NeverPaid())
rs_never_paid, complement_never_paid = log_view.evaluate_query('rs_never_paid', complement_only_fine, query_never_paid)
_ = log_view.characterize_result_set_with_reference_log(rs_never_paid, complement_never_paid, characterizer_name='set-cardinality')
